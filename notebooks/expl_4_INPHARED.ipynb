# %% [markdown]
# # INPHARED
#
#
# [GitHub - Installation](https://github.com/RyanCook94/inphared/tree/main?tab=readme-ov-file)
#
# Inphared is a perl script and is used directly from the console. Ideally we'll use it on the servers only.
#
#
# Requests failing:
# - add -email in the efetch requests
# - maybe check the weird space in the nquire requests (no nquire in the code, but generated from the efetch.. tbc)
