# %% [markdown]
# # VHRdb
#
# Exploration of the Viral Host Range database from Pasteur Institute [VRHdb](https://hub.pages.pasteur.fr/viralhostrangedb/)
#
# Only interactions are pressented, unfortunately most of the sources (such as the Félix d'Hérelle collection) do not provide the sequences, only interactions. The phages and hosts with available public sequences have the NCBI identifier given and can be retrieved.
#
# TODO: Before retrieving anything, check if the sequence / ID is already present with the phagescope metadata.
#
#
# **WARNING:** The IDs are sometimes 'str' sometimes 'int'.
#
#
# **The Gaborieaux et al data** seems to be accessible somehow on the NCBI even if the records in VHRdb are not linked. Check https://www.ncbi.nlm.nih.gov/bioproject/PRJEB39252/. Check 001-031-c1 -> https://www.ncbi.nlm.nih.gov/datasets/genome/GCA_903971915.1/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import json
import requests
import re

import os
import warnings

from Bio import Entrez

# %%
import requests
import pandas as pd

# Step 1: Download JSON from a URL
def download_json_from_url(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"[ERROR] Failed to fetch JSON from {url}: {e}")
        return None

# Step 2: Convert JSON to DataFrame (with automatic structure detection)
def json_to_df(json_data):
    if json_data is None:
        return None

    # Case 1: JSON has "results" key (e.g., paginated API)
    if isinstance(json_data, dict) and "results" in json_data:
        json_data = json_data["results"]

    # Case 2: JSON is already a list of records
    if isinstance(json_data, list):
        return pd.DataFrame(json_data)

    # Case 3: JSON is a dict of dicts
    if isinstance(json_data, dict):
        return pd.DataFrame.from_dict(json_data, orient='index')

    print("[WARNING] Unrecognized JSON structure; cannot convert to DataFrame.")
    return None

# VHRdb API endpoints
VHRdb_links = {
    "global_scheme": "https://viralhostrangedb.pasteur.cloud/api/global-response/?format=json",
    "agregated_resp": "https://viralhostrangedb.pasteur.cloud/api/aggregated-responses/?allow_overflow=true&format=json",
    "per_data_source": "https://viralhostrangedb.pasteur.cloud/api/responses/?allow_overflow=true&format=json",
    "virus": "https://viralhostrangedb.pasteur.cloud/api/virus/?format=json",
    "host": "https://viralhostrangedb.pasteur.cloud/api/host/?format=json",
    "source": "https://viralhostrangedb.pasteur.cloud/api/data-source/?format=json"
}

# Step 1: Download JSONs
VHRdb_global_scheme_json = download_json_from_url(VHRdb_links["global_scheme"])
VHRdb_agregated_resp_json = download_json_from_url(VHRdb_links["agregated_resp"])
VHRdb_per_data_source_json = download_json_from_url(VHRdb_links["per_data_source"])
VHRdb_virus_json = download_json_from_url(VHRdb_links["virus"])
VHRdb_host_json = download_json_from_url(VHRdb_links["host"])
VHRdb_source_json = download_json_from_url(VHRdb_links["source"])

# Step 2: Convert to DataFrames
VHRdb_global_scheme_df = json_to_df(VHRdb_global_scheme_json)
VHRdb_agregated_resp_df = json_to_df(VHRdb_agregated_resp_json)
VHRdb_per_data_source_df = json_to_df(VHRdb_per_data_source_json)
VHRdb_virus_df = json_to_df(VHRdb_virus_json)
VHRdb_host_df = json_to_df(VHRdb_host_json)
VHRdb_source_df = json_to_df(VHRdb_source_json)

# Step 3: Check format

# Convert VHRdb_agregated_resp_df index to integers
VHRdb_agregated_resp_df.index = VHRdb_agregated_resp_df.index.astype(int)
# Same for columns
VHRdb_agregated_resp_df.columns = VHRdb_agregated_resp_df.columns.astype(int)

# %%
VHRdb_virus_df
# Out:
#               name short_name identifier  is_ncbi_identifier_value  \
# 0                1       None   KP869100                      True
# 1                1       None                                False
# 2               10       None   KP869108                      True
# 3     109 Lindberg       None                                False
# 4    10 heidelberg       None                                False
# ..             ...        ...        ...                       ...
# 867              χ       None  712913869                     False
# 868              ψ       None                                False
# 869          ψYS40       None  NC_008584                      True
# 870              ω       None                                False
# 871             Ω8       None                                False
#
#      her_identifier   tax_id    id
# 0             255.0  1508671   308
# 1              67.0     None   963
# 2             264.0  1508672  1210
# 3              12.0     None   914
# 4             437.0     None  1376
# ..              ...      ...   ...
# 867            95.0     None   991
# 868           305.0     None  1250
# 869           473.0   407392  1404
# 870           189.0     None  1139
# 871           315.0     None   770
#
# [872 rows x 7 columns]

# %%
VHRdb_agregated_resp_df
# Out:
#                         15                       20     \
# 247   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 253   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 254   {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
# 255   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 256   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# ...                       ...                      ...
# 5707                      NaN                      NaN
# 5708                      NaN                      NaN
# 5709                      NaN                      NaN
# 5710                      NaN                      NaN
# 5711                      NaN                      NaN
#
#                         49                       50     \
# 247   {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
# 253   {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
# 254   {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
# 255   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 256   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# ...                       ...                      ...
# 5707                      NaN                      NaN
# 5708                      NaN                      NaN
# 5709                      NaN                      NaN
# 5710                      NaN                      NaN
# 5711                      NaN                      NaN
#
#                         51                       53     \
# 247   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 253   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 254   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 255   {'val': 0.0, 'diff': 1}  {'val': 1.0, 'diff': 1}
# 256   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# ...                       ...                      ...
# 5707                      NaN                      NaN
# 5708                      NaN                      NaN
# 5709                      NaN                      NaN
# 5710                      NaN                      NaN
# 5711                      NaN                      NaN
#
#                         54                       55     \
# 247   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 253   {'val': 2.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 254   {'val': 2.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 255   {'val': 1.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 256   {'val': 1.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# ...                       ...                      ...
# 5707                      NaN                      NaN
# 5708                      NaN                      NaN
# 5709                      NaN                      NaN
# 5710                      NaN                      NaN
# 5711                      NaN                      NaN
#
#                         57                       591    ...  \
# 247   {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}  ...
# 253   {'val': 1.0, 'diff': 1}  {'val': 1.0, 'diff': 1}  ...
# 254   {'val': 2.0, 'diff': 1}  {'val': 2.0, 'diff': 1}  ...
# 255   {'val': 2.0, 'diff': 1}  {'val': 2.0, 'diff': 1}  ...
# 256   {'val': 2.0, 'diff': 1}  {'val': 2.0, 'diff': 1}  ...
# ...                       ...                      ...  ...
# 5707                      NaN                      NaN  ...
# 5708                      NaN                      NaN  ...
# 5709                      NaN                      NaN  ...
# 5710                      NaN                      NaN  ...
# 5711                      NaN                      NaN  ...
#
#                         12358                    12360  \
# 247                       NaN                      NaN
# 253                       NaN                      NaN
# 254                       NaN                      NaN
# 255                       NaN                      NaN
# 256                       NaN                      NaN
# ...                       ...                      ...
# 5707  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5708  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5709  {'val': 2.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5710  {'val': 2.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5711  {'val': 2.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
#
#                         12361                    12362  \
# 247                       NaN                      NaN
# 253                       NaN                      NaN
# 254                       NaN                      NaN
# 255                       NaN                      NaN
# 256                       NaN                      NaN
# ...                       ...                      ...
# 5707  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5708  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5709  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5710  {'val': 1.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5711  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
#
#                         12363                    12364  \
# 247                       NaN                      NaN
# 253                       NaN                      NaN
# 254                       NaN                      NaN
# 255                       NaN                      NaN
# 256                       NaN                      NaN
# ...                       ...                      ...
# 5707  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5708  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5709  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5710  {'val': 1.0, 'diff': 1}  {'val': 1.0, 'diff': 1}
# 5711  {'val': 1.0, 'diff': 1}  {'val': 1.0, 'diff': 1}
#
#                         12365                    12367  \
# 247                       NaN                      NaN
# 253                       NaN                      NaN
# 254                       NaN                      NaN
# 255                       NaN                      NaN
# 256                       NaN                      NaN
# ...                       ...                      ...
# 5707  {'val': 1.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5708  {'val': 0.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5709  {'val': 2.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5710  {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
# 5711  {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
#
#                         12368                    12369
# 247                       NaN                      NaN
# 253                       NaN                      NaN
# 254                       NaN                      NaN
# 255                       NaN                      NaN
# 256                       NaN                      NaN
# ...                       ...                      ...
# 5707  {'val': 2.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5708  {'val': 2.0, 'diff': 1}  {'val': 0.0, 'diff': 1}
# 5709  {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
# 5710  {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
# 5711  {'val': 0.0, 'diff': 1}  {'val': 2.0, 'diff': 1}
#
# [872 rows x 2451 columns]

# %% [markdown]
# Virus IDs and Host IDs in the agregated response seem to intersect, so they have to be treated carefully.
#
#
# Attention: ID's are read as strings first -> convert to integers !

# %%
virus_agg_ids = VHRdb_agregated_resp_df.index.tolist()
hosts_agg_ids = VHRdb_agregated_resp_df.columns.tolist()

virus_ids = VHRdb_virus_df["id"].tolist()
hosts_ids = VHRdb_host_df["id"].tolist()

# get intersection of virus and hosts
intersection_agg = set(virus_agg_ids).intersection(set(hosts_agg_ids))
intersection_virus_ids = set(hosts_ids).intersection(set(virus_agg_ids))

# Print the IDs
print("Virus IDs from aggregated response:", sorted(virus_agg_ids))
print("Host IDs from aggregated response:", sorted(hosts_agg_ids))
print("Virus IDs from VHRdb virus list:", sorted(virus_ids))
print("Host IDs from VHRdb host list:", sorted(hosts_ids))

# Print the intersection
print("Intersection of virus and hosts IDs:", intersection_agg)
print("Intersection of virus IDs from aggregated response and virus list:", intersection_virus_ids)

print("---------------------------------------------------------------------------")
print("Virus and Hosts with NCBI identifiers")

# Virus IDs with an identifier and is_ncbi_identifier_value = True
VHRdb_virus_ncbi = VHRdb_virus_df[VHRdb_virus_df["is_ncbi_identifier_value"] == True]["id"].tolist()
# Host IDs with an identifier and is_ncbi_identifier_value = True
VHRdb_host_ncbi = VHRdb_host_df[VHRdb_host_df["is_ncbi_identifier_value"] == True]["id"].tolist()
print(f"{len(VHRdb_virus_ncbi)} Virus IDs with NCBI identifier:", sorted(VHRdb_virus_ncbi))
print(f"{len(VHRdb_host_ncbi)} Host IDs with NCBI identifier:", sorted(VHRdb_host_ncbi))

# Now we need to check how many of these IDs are in the aggregated response and have interaction data.
# Out:
# Virus IDs from aggregated response: [247, 253, 254, 255, 256, 262, 308, 311, 369, 371, 372, 375, 377, 429, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 568, 679, 680, 681, 690, 691, 692, 693, 694, 695, 696, 697, 699, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 929, 930, 931, 932, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 17 ...
# Host IDs from aggregated response: [15, 20, 49, 50, 51, 53, 54, 55, 57, 591, 913, 919, 920, 974, 975, 976, 977, 978, 979, 980, 981, 1025, 1026, 1029, 1030, 1210, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1376, 1377, 1378, 1379, 1381, 1382, 1383, 1385, 1386, 1387, 1388, 1390, 1391, 1489, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966 ...
# Virus IDs from VHRdb virus list: [247, 253, 254, 255, 256, 262, 308, 311, 369, 371, 372, 375, 377, 429, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 568, 679, 680, 681, 690, 691, 692, 693, 694, 695, 696, 697, 699, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 929, 930, 931, 932, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, ...
# Host IDs from VHRdb host list: [15, 20, 49, 50, 51, 53, 54, 55, 57, 591, 913, 919, 920, 974, 975, 976, 977, 978, 979, 980, 981, 1025, 1026, 1029, 1030, 1210, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1376, 1377, 1378, 1379, 1381, 1382, 1383, 1385, 1386, 1387, 1388, 1390, 1391, 1489, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 19 ...
# Intersection of virus and hosts IDs: {2099, 2116, 2117, 2118, 2119, 2120, 2121, 2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888, 913, 919, 920, 974, 975, 976, 977, 978, 979, 980, 981, 1210, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1376, 1377, 1378, 1379, 1381, 1382, 1383, 1385, 1386, 1387, 1388, 1390, 1391, 1489, 1493, 1494, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1791, 1792, 1852, 1853, 1854, 1861, 1862, 1864, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 2040}
# Intersection of virus IDs from aggregated response and virus list: {2099, 2116, 2117, 2118, 2119, 2120, 2121, 2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888, 913, 919, 920, 974, 975, 976, 977, 978, 979, 980, 981, 1210, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1376, 1377, 1378, 1379, 1381, 1382, 1383, 1385, 1386, 1387, 1388, 1390, 1391, 1489, 1493, 1494, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1791, 1792, 1852, 1853, 1854, 1861, 1862, 1864, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 2040}
# ---------------------------------------------------------------------------
# Virus and Hosts with NCBI identifiers
# 316 Virus IDs with NCBI identifier: [308, 311, 369, 371, 372, 568, 679, 680, 681, 690, 691, 692, 693, 694, 695, 696, 697, 699, 769, 771, 772, 773, 774, 775, 776, 777, 778, 779, 910, 912, 913, 915, 919, 928, 960, 961, 980, 981, 994, 995, 996, 997, 1001, 1002, 1004, 1005, 1006, 1080, 1081, 1082, 1083, 1084, 1085, 1090, 1094, 1095, 1096, 1098, 1099, 1100, 1103, 1108, 1111, 1119, 1121, 1132, 1137, 1138, 1143, 1153, 1154, 1155, 1158, 1159, 1161, 1167, 1170, 1172, 1174, 1175, 1176, 1177, 1187, 1188, 1190, 1191, 1192, 1194, 1197, 1198, 1202, 1203, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1222, 1226, 1228, 1230, 1233, 1235, 1258, 1263, 1275, 1279, 1295, 1303, 1310, 1311, 1315, 1316, 1318, 1319, 1320, 1324, 1325, 1326, 1328, 1330, 1332, 1333, 1336, 1338, 1340, 1342, 1347, 1351, 1362, 1363, 1364, 1378, 1379, 1380, 1382, 1386, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1397, 1398, 1399, 1400, 1402, 1404, 1405, 1406, 1409, 1410, 1411, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1444, 1445, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1509, 1510, 1511, 1512, 1513, 1665, 1666, 1667, 1668, 1670, 1676, 1677, 1678, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1697, 1699, 1700, 1702, 1703, 1704, 1705, 1706, 1721, 1722, 1723, 1724, 1740, 1741, 1742, 1743, 1747, 1748, 1749, 1763, 1771, 1776, 1777, 1791, 1792, 1881, 1882, 1884, 1885, 1888, 1889, 1890, 1891, 1893, 1895, 1896, 2099, 2116, 2118, 2119, 2120, 2121, 2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888, 5702, 5703, 5704, 5705, 5706, 5707, 5708, 5709, 5710, 5711, 5767, 5768]
# 28 Host IDs with NCBI identifier: [1373, 1374, 1377, 1382, 1390, 1489, 1493, 1494, 1495, 2455, 2458, 2466, 3145, 3146, 3147, 3148, 3150, 3153, 3155, 3195, 3270, 3335, 3338, 3339, 3591, 3592, 12365, 12368]

# %%
# Elements with NCBI identifiers in the aggregated response


# Get elements from VHRdb_agregated_resp_df with index in VHRdb_virus_ncbi
vidx_lst = [vid for vid in VHRdb_agregated_resp_df.index if vid in VHRdb_virus_ncbi]
VHRdb_agregated_resp_df_vncbi = VHRdb_agregated_resp_df.loc[vidx_lst]

# filter columns with hosts that have NCBI identifiers, resulting in both virus and host IDs with accessible sequences
hidx_lst = [hid for hid in VHRdb_agregated_resp_df.columns if hid in VHRdb_host_ncbi]
VHRdb_agregated_resp_df_vhncbi = VHRdb_agregated_resp_df_vncbi[hidx_lst]

print(f"Shape of VHRdb_agregated_resp_df with both virus and host NCBI IDs: {VHRdb_agregated_resp_df_vhncbi.shape}")
print(f"There are {len(VHRdb_agregated_resp_df_vhncbi.index)} virus IDs and {len(VHRdb_agregated_resp_df_vhncbi.columns)} host IDs with NCBI identifiers in the aggregated response.")

# Plot the heatmap of interactions: NaN are in grey, {'val': 0.0, 'diff': 1} in green, {'val': 1.0, 'diff': 1} in orange, {'val': 2.0, 'diff': 1} in red. 
# extract the values from the dictionary in the DataFrame if the value is a dictionary
VHRdb_agregated_resp_df_vhncbi_plt = VHRdb_agregated_resp_df_vhncbi.map(lambda x: x['val'] if isinstance(x, dict) else np.nan)
print(f"Existing interaction data: {VHRdb_agregated_resp_df_vhncbi_plt.notnull().sum().sum()}")
print(f"No interaction data data: {VHRdb_agregated_resp_df_vhncbi_plt.isnull().sum().sum()}")
# Out:
# Shape of VHRdb_agregated_resp_df with both virus and host NCBI IDs: (316, 28)
# There are 316 virus IDs and 28 host IDs with NCBI identifiers in the aggregated response.
# Existing interaction data: 228
# No interaction data data: 8620

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(VHRdb_agregated_resp_df_vhncbi_plt, cmap="RdYlGn", annot=False, fmt=".1f", cbar_kws={'label': 'Interaction Value'})
plt.title("Interactions between Virus and Host with NCBI Identifiers")
plt.xlabel("Host IDs")
plt.ylabel("Virus IDs")
plt.show()

# %%
from venn import venn
import matplotlib.pyplot as plt

# Préparation des données pour la bibliothèque `venn`
sets = {
    "Virus Agg IDs": set(virus_agg_ids),
    "Host Agg IDs": set(hosts_agg_ids),
    "Virus IDs": set(virus_ids),
    "Host IDs": set(hosts_ids)
}

# Tracer le Venn diagram à 4 ensembles
plt.figure(figsize=(10, 8))
venn(sets)
plt.title("Venn Diagram of Virus and Host ID Sets (4 ensembles)")
plt.show()

# %%
print(sorted(virus_agg_ids))
print(sorted(hosts_agg_ids))
print(sorted(virus_ids))
print(sorted(hosts_ids))
# Out:
# [247, 253, 254, 255, 256, 262, 308, 311, 369, 371, 372, 375, 377, 429, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 568, 679, 680, 681, 690, 691, 692, 693, 694, 695, 696, 697, 699, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 929, 930, 931, 932, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 17 ...
# [15, 20, 49, 50, 51, 53, 54, 55, 57, 591, 913, 919, 920, 974, 975, 976, 977, 978, 979, 980, 981, 1025, 1026, 1029, 1030, 1210, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1376, 1377, 1378, 1379, 1381, 1382, 1383, 1385, 1386, 1387, 1388, 1390, 1391, 1489, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 197 ...
# [247, 253, 254, 255, 256, 262, 308, 311, 369, 371, 372, 375, 377, 429, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 568, 679, 680, 681, 690, 691, 692, 693, 694, 695, 696, 697, 699, 741, 742, 743, 744, 745, 746, 747, 748, 749, 750, 751, 752, 753, 754, 755, 756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775, 776, 777, 778, 779, 903, 904, 905, 906, 907, 908, 909, 910, 911, 912, 913, 914, 915, 916, 917, 918, 919, 920, 921, 922, 923, 924, 925, 926, 927, 928, 929, 930, 931, 932, 934, 935, 936, 937, 938, 939, 940, 941, 942, 943, 944, 945, 946, 947, 948, 949, 950, 951, 952, 953, 954, 955, 956, 957, 958, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091, 1092, 1093, 1094, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109, 1110, 1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121, 1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132, 1133, 1134, 1135, 1136, 1137, 1138, 1139, 1140, 1141, 1142, 1143, 1144, 1145, 1146, 1147, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1156, 1157, 1158, 1159, 1160, 1161, 1162, 1163, 1164, 1165, 1166, 1167, 1168, 1169, 1170, 1171, 1172, 1173, 1174, 1175, 1176, 1177, 1178, 1179, 1180, 1181, 1182, 1183, 1184, 1185, 1186, 1187, 1188, 1189, 1190, 1191, 1192, 1193, 1194, 1195, 1196, 1197, 1198, 1199, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1212, 1213, 1214, 1215, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1288, 1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1375, 1376, 1377, 1378, 1379, 1380, 1381, 1382, 1383, 1384, 1385, 1386, 1387, 1388, 1389, 1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1400, 1401, 1402, 1403, 1404, 1405, 1406, 1407, 1408, 1409, 1410, 1411, 1412, 1413, 1414, 1415, 1416, 1417, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1427, 1428, 1429, 1430, 1431, 1432, 1433, 1434, 1435, 1436, 1437, 1438, 1439, 1440, 1441, 1442, 1443, 1444, 1445, 1446, 1447, 1448, 1449, 1450, 1451, 1452, 1453, 1454, 1455, 1456, 1457, 1458, 1459, 1460, 1461, 1462, 1463, 1464, 1465, 1466, 1467, 1468, 1469, 1470, 1471, 1472, 1473, 1474, 1475, 1476, 1477, 1478, 1479, 1480, 1481, 1482, 1483, 1484, 1485, 1486, 1487, 1488, 1489, 1490, 1491, 1492, 1493, 1494, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 17 ...
# [15, 20, 49, 50, 51, 53, 54, 55, 57, 591, 913, 919, 920, 974, 975, 976, 977, 978, 979, 980, 981, 1025, 1026, 1029, 1030, 1210, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1376, 1377, 1378, 1379, 1381, 1382, 1383, 1385, 1386, 1387, 1388, 1390, 1391, 1489, 1493, 1494, 1495, 1496, 1497, 1498, 1499, 1500, 1501, 1502, 1503, 1504, 1505, 1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1530, 1531, 1532, 1533, 1534, 1535, 1536, 1537, 1538, 1539, 1540, 1541, 1542, 1543, 1544, 1545, 1546, 1547, 1548, 1549, 1550, 1551, 1552, 1553, 1554, 1555, 1556, 1557, 1558, 1559, 1560, 1561, 1562, 1563, 1564, 1565, 1566, 1567, 1568, 1569, 1570, 1571, 1572, 1573, 1574, 1575, 1576, 1577, 1578, 1579, 1580, 1581, 1582, 1583, 1584, 1585, 1586, 1587, 1588, 1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598, 1599, 1600, 1601, 1602, 1603, 1604, 1605, 1606, 1607, 1608, 1609, 1610, 1611, 1612, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1623, 1624, 1625, 1626, 1627, 1628, 1629, 1630, 1631, 1632, 1633, 1634, 1635, 1636, 1637, 1638, 1639, 1640, 1641, 1642, 1643, 1644, 1645, 1646, 1647, 1648, 1649, 1650, 1651, 1652, 1653, 1654, 1655, 1656, 1657, 1658, 1659, 1660, 1661, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809, 1810, 1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 197 ...

# %% [markdown]
# ## Exploration of sequence availability

# %%
VHRdb_virus_df
# Out:
#               name short_name identifier  is_ncbi_identifier_value  \
# 0                1       None   KP869100                      True
# 1                1       None                                False
# 2               10       None   KP869108                      True
# 3     109 Lindberg       None                                False
# 4    10 heidelberg       None                                False
# ..             ...        ...        ...                       ...
# 867              χ       None  712913869                     False
# 868              ψ       None                                False
# 869          ψYS40       None  NC_008584                      True
# 870              ω       None                                False
# 871             Ω8       None                                False
#
#      her_identifier   tax_id    id
# 0             255.0  1508671   308
# 1              67.0     None   963
# 2             264.0  1508672  1210
# 3              12.0     None   914
# 4             437.0     None  1376
# ..              ...      ...   ...
# 867            95.0     None   991
# 868           305.0     None  1250
# 869           473.0   407392  1404
# 870           189.0     None  1139
# 871           315.0     None   770
#
# [872 rows x 7 columns]

# %%
# Sequences on ncbi are considered as available, so we have 316/556 sequences available for the phages. 
VHRdb_virus_df.groupby("is_ncbi_identifier_value").size()
# Out:
# is_ncbi_identifier_value
# False    556
# True     316
# dtype: int64

# %%
# join VHRdb_virus and VHRdb_source on id

VHRdb_virus_source = VHRdb_virus_df.merge(VHRdb_source_df, on="id", how="inner", suffixes=("", "_source"))
VHRdb_virus_source
# Out:
# Empty DataFrame
# Columns: [name, short_name, identifier, is_ncbi_identifier_value, her_identifier, tax_id, id, name_source, description, public, creation_date, last_edition_date]
# Index: []

# %%
# df_agregated_resp + VHRdb_virus

# %%
# List of id where identifier is available
ncbi_available = VHRdb_virus_df[VHRdb_virus_df["is_ncbi_identifier_value"] == True]["id"].tolist()
print(f"Number of phages with NCBI identifier: {len(ncbi_available)}")
print(f"Phages with NCBI identifier: {ncbi_available}")
# Out:
# Number of phages with NCBI identifier: 316
# Phages with NCBI identifier: [308, 1210, 1211, 915, 1212, 772, 1213, 1363, 1155, 1214, 1215, 1391, 1188, 1364, 960, 981, 1228, 1394, 1468, 1205, 1001, 1002, 1174, 980, 311, 994, 1362, 997, 1206, 1004, 1005, 996, 1207, 1006, 1208, 1187, 910, 1175, 777, 1406, 1176, 1395, 1209, 1153, 1154, 1411, 1336, 1158, 1447, 1448, 1449, 1450, 1463, 1451, 1462, 1464, 1452, 1453, 1454, 1455, 1456, 1465, 1471, 1457, 1459, 1460, 1461, 1493, 1492, 1159, 5707, 1428, 1409, 1665, 1666, 1090, 1667, 995, 1668, 1480, 1191, 1351, 1161, 1481, 1347, 1389, 1388, 1084, 1320, 1137, 1326, 1670, 1472, 5704, 1379, 1676, 1677, 1678, 1423, 1422, 699, 1416, 1417, 2099, 5767, 5768, 5708, 1172, 1315, 1792, 1791, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1325, 1194, 1233, 5709, 1473, 1279, 1415, 1310, 1402, 5710, 5711, 913, 912, 1691, 1692, 1121, 1222, 1132, 1295, 1397, 5703, 5702, 1693, 1324, 1338, 773, 1697, 1699, 1513, 1512, 1511, 1405, 1316, 961, 1881, 1700, 1197, 1342, 1143, 1328, 696, 1275, 5705, 1470, 568, 1418, 1382, 697, 1419, 1167, 1392, 1413, 919, 1702, 1703, 1414, 1704, 1705, 2878, 1424, 771, 680, 681, 679, 1706, 1202, 778, 1721, 1722, 1723, 1724, 1138, 1100, 1740, 1741, 1742, 1743, 1479, 1747, 1748, 1749, 1466, 1763, 1177, 1303, 928, 1393, 1111, 1398, 695, 1467, 1429, 690, 691, 692, 693, 694, 1340, 1096, 1771, 1333, 1895, 1896, 1893, 1882, 1884, 1885, 2116, 2118, 2120, 2119, 1888, 1889, 1890, 1891, 1469, 1263, 1203, 1311, 2879, 2880, 2881, 2882, 2883, 775, 1170, 2884, 2885, 2886, 2887, 2888, 5706, 1487, 1486, 1488, 1390, 1235, 1400, 1510, 1108, 1509, 1085, 1444, 1445, 1420, 1427, 1082, 1378, 1474, 1478, 1098, 1080, 1386, 1099, 1489, 1485, 1490, 1491, 1494, 1482, 1483, 1484, 369, 371, 779, 372, 776, 1081, 1776, 1425, 1399, 1380, 2121, 1476, 1226, 1119, 1083, 1777, 1475, 1477, 1426, 1330, 1258, 1094, 769, 1192, 1332, 1190, 1410, 1230, 1319, 1318, 1103, 1095, 774, 1198, 1404]

# %%
# visualization of the IDs of VHRdb_host["id"] and VHRdb_virus["id"]
plt.figure(figsize=(10, 6))
sns.histplot(VHRdb_host_df["id"], bins=30, kde=True, color='blue', label='Host IDs')
sns.histplot(VHRdb_virus_df["id"], bins=30, kde=True, color='red', label='Virus IDs')
plt.title('Distribution of Host and Virus IDs')
plt.xlabel('ID')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# common IDs between VHRdb_host and VHRdb_virus
common_ids = set(VHRdb_host_df["id"]).intersection(set(VHRdb_virus_df["id"]))
print(f"Number of common IDs: {len(common_ids)}")
print(f"Common IDs: {common_ids}")
# Out:
# Number of common IDs: 363
# Common IDs: {2099, 2116, 2117, 2118, 2119, 2120, 2121, 2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888, 913, 919, 920, 974, 975, 976, 977, 978, 979, 980, 981, 1210, 1216, 1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224, 1225, 1226, 1227, 1228, 1229, 1230, 1231, 1232, 1233, 1234, 1235, 1236, 1237, 1238, 1239, 1240, 1241, 1242, 1243, 1244, 1245, 1246, 1247, 1248, 1249, 1250, 1251, 1252, 1253, 1254, 1255, 1256, 1257, 1258, 1259, 1260, 1261, 1262, 1263, 1264, 1265, 1266, 1267, 1268, 1269, 1270, 1271, 1272, 1273, 1274, 1275, 1276, 1277, 1278, 1279, 1280, 1281, 1282, 1283, 1284, 1285, 1286, 1287, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1303, 1304, 1305, 1306, 1307, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1318, 1319, 1320, 1321, 1322, 1323, 1324, 1325, 1326, 1327, 1328, 1329, 1330, 1331, 1332, 1333, 1334, 1335, 1336, 1337, 1338, 1339, 1340, 1341, 1342, 1343, 1344, 1345, 1346, 1347, 1348, 1349, 1350, 1351, 1352, 1353, 1354, 1355, 1356, 1357, 1358, 1359, 1360, 1361, 1362, 1363, 1364, 1365, 1366, 1367, 1368, 1369, 1370, 1371, 1372, 1373, 1374, 1376, 1377, 1378, 1379, 1381, 1382, 1383, 1385, 1386, 1387, 1388, 1390, 1391, 1489, 1493, 1494, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1662, 1663, 1664, 1665, 1666, 1667, 1668, 1669, 1670, 1671, 1672, 1673, 1674, 1675, 1676, 1677, 1678, 1679, 1680, 1681, 1682, 1683, 1684, 1685, 1686, 1687, 1688, 1689, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1791, 1792, 1852, 1853, 1854, 1861, 1862, 1864, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876, 1877, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 2040}

# %% [markdown]
# # Try to get ID from Gaborieau isolates identifiers
#
# Hosts might have an NCBI identifier but most don't. It seems that some of the records are stored in the NCBI databases and using the "name" of the host matches the isolate id. However, manually verifying if the records matche the names is not possible.

# %%
from xml.etree import ElementTree

# Replace with your email — required by NCBI
Entrez.email = "your.email@example.com"

def search_ncbi_by_isolate(isolate_id, db="nucleotide", retmax=2000, verbose=True):
    """
    Search NCBI using an isolate identifier and return matching record IDs.

    Parameters:
        isolate_id (str): The isolate identifier to search for.
        db (str): NCBI database to search (default: "nucleotide").
        retmax (int): Maximum number of records to return.
        verbose (bool): Whether to print intermediate information.

    Returns:
        List[str]: List of NCBI IDs (e.g., GenBank accession numbers).
    """

    # Format the search term — using [isolate] tag can help refine
    search_term = f'"{isolate_id}"[Isolate]'

    if verbose:
        print(f"Searching NCBI '{db}' database for: {search_term}")

    # Run the Entrez esearch
    handle = Entrez.esearch(db=db, term=search_term, retmax=retmax)
    results = Entrez.read(handle)
    handle.close()

    ids = results.get("IdList", [])

    if verbose:
        print(f"Found {len(ids)} record(s).")

    return ids

def fetch_summary(ids, db="nucleotide", verbose=True):
    """
    Fetch summaries (titles, accession numbers, etc.) for given NCBI IDs.

    Parameters:
        ids (List[str]): List of NCBI IDs to fetch.
        db (str): Database to fetch from.

    Returns:
        List[dict]: Summary information for each ID.
    """
    if not ids:
        return []

    handle = Entrez.esummary(db=db, id=",".join(ids))
    records = Entrez.read(handle)
    handle.close()

    if verbose:
        for record in records:
            print(f"{record['Caption']} | {record['Title']}")

    return records

# Example usage
if __name__ == "__main__":
    isolate_identifier = "001-031-c1"  # <-- Replace with your isolate ID
    ids = search_ncbi_by_isolate(isolate_identifier, verbose=False)
    print(f"Found IDs: {ids}")
    summaries = fetch_summary(ids)
# Out:
# Found IDs: ['2094213945', '2094213944', '2094213943', '2094213942', '2094213941', '2094213940', '2094213939', '2094213938', '2094213937', '2094213936', '2094213935', '2094213934', '2094213933', '2094213932', '2094213931', '2094213930', '2094213929', '2094213928', '2094213927', '2094213926', '2094213925', '2094213924', '2094213923', '2094213922', '2094213921', '2094213920', '2094213919', '2094213918', '2094213917', '2094213916', '2094213915', '2094213914', '2094213913', '2094213912', '2094213911', '2094213910', '2094213909', '2094213908', '2094213907', '2094213906', '2094213905', '2094213904', '2094213903', '2094213902', '2094213901', '2094213900', '2094213899', '2094213898', '2094213897', '2094213896', '2094213895', '2094213894', '2094213893', '2094213892', '2094213891', '2094213890', '2094213889', '2094213888', '2094213887', '2094213886', '2094213885', '2094213884', '2094213883', '2094213882', '2094213881', '2094213880', '2094213879', '2094213878', '2094213877', '2094213876', '2094213875', '2094213874', '2094213873', '2094213872', '2094213871', '2094213870', '2094213869', '2094213868', '2094213867', '2094213866', '2094213865', '2094213864', '2094213863', '2094213862', '2094213861', '2094213860', '2094213859', '2094213858', '2094213857', '2094213856', '2094213855', '2094213854', '2094213853', '2094213852', '2094213851', '2094213850', '2094213849', '2094213848', '2094213847', '2094213846', '2094213845', '2094213844', '2094213843', '2094213842', '2094213841', '2094213840', '2094213839', '2094213838', '2094213837', '2094213836', '2094213835', '2094213834', '2094213833', '2094213832', '2094213831', '2094213830', '2094213829', '2094213828', '2094213827', '2094213826', '2094213825', '2094213824', '2094213823', '2094213822', '2094213821', '2094213820', '2094213819', '2094213818', '2094213817', '2094213816', '2094213815', '2094213814', '2094213813', '2094213812', '2094213811', '2094213810', '2094213809', '2094213808', '2094213807', '2094213806', '2094213805', '2094213804', '2094213803', '2094213802', '2094213801', '2094213800', '2094213799', '2094213798', '2094213797', '2094213796', '2094213795', '2094213794', '2094213793', '2094213792', '2094213791', '2094213790', '2094213789', '2094213788', '2094213787', '2094213786', '2094213785', '2094213784', '2094213783', '2094213782', '2094213781', '2094213780', '2094213779', '2094213778', '2094213777', '2094213776', '2094213775', '2094213774', '2094213773', '2094213772', '2094213771', '2094213770', '2094213769', '2094213768', '2094213767', '2094213766', '2094213765', '2094213764', '2094213763', '2094213762', '2094213761', '2094213760', '2094213759', '2094213758', '2094213757', '2094213756', '2094213755', '2094213754', '2094213753', '2094213752', '2094213751', '2094213750', '2094213749', '2094213748', '2094213747', '2094213746', '2094213745', '2094213744', '2094213743', '2094213742', '2094213741', '2094213740', '2094213739', '2094213738', '2094213737', '2094213736', '2094213735', '2094213734', '2094213733', '2094213732', '2094213731', '2094213730', '2094213729', '2094213728', '2094213727', '2094213726', '2094213725', '2094213724', '2094213723', '2094213722', '2094213721', '2094213720', '2094213719', '2094213718', '2094213717', '2094213716', '2094213715', '2094213714', '2094213713', '2094213712', '2094213711', '2094213710', '2094213709', '2094213708', '2094213707', '2094213706', '2094213705', '2094213704', '2094213703', '2094213702', '2094213701']
# CAJCMC000000000 | Escherichia coli isolate 001-031-c1, whole genome shotgun sequencing project
# CAJCMC010000001 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig1, whole genome shotgun sequence
# CAJCMC010000002 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig2, whole genome shotgun sequence
# CAJCMC010000003 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig3, whole genome shotgun sequence
# CAJCMC010000004 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig4, whole genome shotgun sequence
# CAJCMC010000005 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig5, whole genome shotgun sequence
# CAJCMC010000006 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig6, whole genome shotgun sequence
# CAJCMC010000007 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig7, whole genome shotgun sequence
# CAJCMC010000008 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig8, whole genome shotgun sequence
# CAJCMC010000009 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig9, whole genome shotgun sequence
# CAJCMC010000010 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig10, whole genome shotgun sequence
# CAJCMC010000011 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig11, whole genome shotgun sequence
# CAJCMC010000012 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig12, whole genome shotgun sequence
# CAJCMC010000013 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig13, whole genome shotgun sequence
# CAJCMC010000014 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig14, whole genome shotgun sequence
# CAJCMC010000015 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig15, whole genome shotgun sequence
# CAJCMC010000016 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig16, whole genome shotgun sequence
# CAJCMC010000017 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig17, whole genome shotgun sequence
# CAJCMC010000018 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig18, whole genome shotgun sequence
# CAJCMC010000019 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig19, whole genome shotgun sequence
# CAJCMC010000020 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig20, whole genome shotgun sequence
# CAJCMC010000021 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig21, whole genome shotgun sequence
# CAJCMC010000022 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig22, whole genome shotgun sequence
# CAJCMC010000023 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig23, whole genome shotgun sequence
# CAJCMC010000024 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig24, whole genome shotgun sequence
# CAJCMC010000025 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig25, whole genome shotgun sequence
# CAJCMC010000026 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig26, whole genome shotgun sequence
# CAJCMC010000027 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig27, whole genome shotgun sequence
# CAJCMC010000028 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig28, whole genome shotgun sequence
# CAJCMC010000029 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig29, whole genome shotgun sequence
# CAJCMC010000030 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig30, whole genome shotgun sequence
# CAJCMC010000031 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig31, whole genome shotgun sequence
# CAJCMC010000032 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig32, whole genome shotgun sequence
# CAJCMC010000033 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig33, whole genome shotgun sequence
# CAJCMC010000034 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig34, whole genome shotgun sequence
# CAJCMC010000035 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig35, whole genome shotgun sequence
# CAJCMC010000036 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig36, whole genome shotgun sequence
# CAJCMC010000037 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig37, whole genome shotgun sequence
# CAJCMC010000038 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig38, whole genome shotgun sequence
# CAJCMC010000039 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig39, whole genome shotgun sequence
# CAJCMC010000040 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig40, whole genome shotgun sequence
# CAJCMC010000041 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig41, whole genome shotgun sequence
# CAJCMC010000042 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig42, whole genome shotgun sequence
# CAJCMC010000043 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig43, whole genome shotgun sequence
# CAJCMC010000044 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig44, whole genome shotgun sequence
# CAJCMC010000045 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig45, whole genome shotgun sequence
# CAJCMC010000046 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig46, whole genome shotgun sequence
# CAJCMC010000047 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig47, whole genome shotgun sequence
# CAJCMC010000048 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig48, whole genome shotgun sequence
# CAJCMC010000049 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig49, whole genome shotgun sequence
# CAJCMC010000050 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig50, whole genome shotgun sequence
# CAJCMC010000051 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig51, whole genome shotgun sequence
# CAJCMC010000052 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig52, whole genome shotgun sequence
# CAJCMC010000053 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig53, whole genome shotgun sequence
# CAJCMC010000054 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig54, whole genome shotgun sequence
# CAJCMC010000055 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig55, whole genome shotgun sequence
# CAJCMC010000056 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig56, whole genome shotgun sequence
# CAJCMC010000057 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig57, whole genome shotgun sequence
# CAJCMC010000058 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig58, whole genome shotgun sequence
# CAJCMC010000059 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig59, whole genome shotgun sequence
# CAJCMC010000060 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig60, whole genome shotgun sequence
# CAJCMC010000061 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig61, whole genome shotgun sequence
# CAJCMC010000062 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig62, whole genome shotgun sequence
# CAJCMC010000063 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig63, whole genome shotgun sequence
# CAJCMC010000064 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig64, whole genome shotgun sequence
# CAJCMC010000065 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig65, whole genome shotgun sequence
# CAJCMC010000066 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig66, whole genome shotgun sequence
# CAJCMC010000067 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig67, whole genome shotgun sequence
# CAJCMC010000068 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig68, whole genome shotgun sequence
# CAJCMC010000069 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig69, whole genome shotgun sequence
# CAJCMC010000070 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig70, whole genome shotgun sequence
# CAJCMC010000071 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig71, whole genome shotgun sequence
# CAJCMC010000072 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig72, whole genome shotgun sequence
# CAJCMC010000073 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig73, whole genome shotgun sequence
# CAJCMC010000074 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig74, whole genome shotgun sequence
# CAJCMC010000075 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig75, whole genome shotgun sequence
# CAJCMC010000076 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig76, whole genome shotgun sequence
# CAJCMC010000077 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig77, whole genome shotgun sequence
# CAJCMC010000078 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig78, whole genome shotgun sequence
# CAJCMC010000079 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig79, whole genome shotgun sequence
# CAJCMC010000080 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig80, whole genome shotgun sequence
# CAJCMC010000081 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig81, whole genome shotgun sequence
# CAJCMC010000082 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig82, whole genome shotgun sequence
# CAJCMC010000083 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig83, whole genome shotgun sequence
# CAJCMC010000084 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig84, whole genome shotgun sequence
# CAJCMC010000085 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig85, whole genome shotgun sequence
# CAJCMC010000086 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig86, whole genome shotgun sequence
# CAJCMC010000087 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig87, whole genome shotgun sequence
# CAJCMC010000088 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig88, whole genome shotgun sequence
# CAJCMC010000089 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig89, whole genome shotgun sequence
# CAJCMC010000090 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig90, whole genome shotgun sequence
# CAJCMC010000091 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig91, whole genome shotgun sequence
# CAJCMC010000092 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig92, whole genome shotgun sequence
# CAJCMC010000093 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig93, whole genome shotgun sequence
# CAJCMC010000094 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig94, whole genome shotgun sequence
# CAJCMC010000095 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig95, whole genome shotgun sequence
# CAJCMC010000096 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig96, whole genome shotgun sequence
# CAJCMC010000097 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig97, whole genome shotgun sequence
# CAJCMC010000098 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig98, whole genome shotgun sequence
# CAJCMC010000099 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig99, whole genome shotgun sequence
# CAJCMC010000100 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig100, whole genome shotgun sequence
# CAJCMC010000101 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig101, whole genome shotgun sequence
# CAJCMC010000102 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig102, whole genome shotgun sequence
# CAJCMC010000103 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig103, whole genome shotgun sequence
# CAJCMC010000104 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig104, whole genome shotgun sequence
# CAJCMC010000105 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig105, whole genome shotgun sequence
# CAJCMC010000106 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig106, whole genome shotgun sequence
# CAJCMC010000107 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig107, whole genome shotgun sequence
# CAJCMC010000108 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig108, whole genome shotgun sequence
# CAJCMC010000109 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig109, whole genome shotgun sequence
# CAJCMC010000110 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig110, whole genome shotgun sequence
# CAJCMC010000111 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig111, whole genome shotgun sequence
# CAJCMC010000112 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig112, whole genome shotgun sequence
# CAJCMC010000113 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig113, whole genome shotgun sequence
# CAJCMC010000114 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig114, whole genome shotgun sequence
# CAJCMC010000115 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig115, whole genome shotgun sequence
# CAJCMC010000116 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig116, whole genome shotgun sequence
# CAJCMC010000117 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig117, whole genome shotgun sequence
# CAJCMC010000118 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig118, whole genome shotgun sequence
# CAJCMC010000119 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig119, whole genome shotgun sequence
# CAJCMC010000120 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig120, whole genome shotgun sequence
# CAJCMC010000121 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig121, whole genome shotgun sequence
# CAJCMC010000122 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig122, whole genome shotgun sequence
# CAJCMC010000123 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig123, whole genome shotgun sequence
# CAJCMC010000124 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig124, whole genome shotgun sequence
# CAJCMC010000125 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig125, whole genome shotgun sequence
# CAJCMC010000126 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig126, whole genome shotgun sequence
# CAJCMC010000127 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig127, whole genome shotgun sequence
# CAJCMC010000128 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig128, whole genome shotgun sequence
# CAJCMC010000129 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig129, whole genome shotgun sequence
# CAJCMC010000130 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig130, whole genome shotgun sequence
# CAJCMC010000131 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig131, whole genome shotgun sequence
# CAJCMC010000132 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig132, whole genome shotgun sequence
# CAJCMC010000133 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig133, whole genome shotgun sequence
# CAJCMC010000134 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig134, whole genome shotgun sequence
# CAJCMC010000135 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig135, whole genome shotgun sequence
# CAJCMC010000136 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig136, whole genome shotgun sequence
# CAJCMC010000137 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig137, whole genome shotgun sequence
# CAJCMC010000138 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig138, whole genome shotgun sequence
# CAJCMC010000139 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig139, whole genome shotgun sequence
# CAJCMC010000140 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig140, whole genome shotgun sequence
# CAJCMC010000141 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig141, whole genome shotgun sequence
# CAJCMC010000142 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig142, whole genome shotgun sequence
# CAJCMC010000143 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig143, whole genome shotgun sequence
# CAJCMC010000144 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig144, whole genome shotgun sequence
# CAJCMC010000145 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig145, whole genome shotgun sequence
# CAJCMC010000146 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig146, whole genome shotgun sequence
# CAJCMC010000147 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig147, whole genome shotgun sequence
# CAJCMC010000148 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig148, whole genome shotgun sequence
# CAJCMC010000149 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig149, whole genome shotgun sequence
# CAJCMC010000150 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig150, whole genome shotgun sequence
# CAJCMC010000151 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig151, whole genome shotgun sequence
# CAJCMC010000152 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig152, whole genome shotgun sequence
# CAJCMC010000153 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig153, whole genome shotgun sequence
# CAJCMC010000154 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig154, whole genome shotgun sequence
# CAJCMC010000155 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig155, whole genome shotgun sequence
# CAJCMC010000156 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig156, whole genome shotgun sequence
# CAJCMC010000157 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig157, whole genome shotgun sequence
# CAJCMC010000158 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig158, whole genome shotgun sequence
# CAJCMC010000159 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig159, whole genome shotgun sequence
# CAJCMC010000160 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig160, whole genome shotgun sequence
# CAJCMC010000161 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig161, whole genome shotgun sequence
# CAJCMC010000162 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig162, whole genome shotgun sequence
# CAJCMC010000163 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig163, whole genome shotgun sequence
# CAJCMC010000164 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig164, whole genome shotgun sequence
# CAJCMC010000165 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig165, whole genome shotgun sequence
# CAJCMC010000166 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig166, whole genome shotgun sequence
# CAJCMC010000167 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig167, whole genome shotgun sequence
# CAJCMC010000168 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig168, whole genome shotgun sequence
# CAJCMC010000169 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig169, whole genome shotgun sequence
# CAJCMC010000170 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig170, whole genome shotgun sequence
# CAJCMC010000171 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig171, whole genome shotgun sequence
# CAJCMC010000172 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig172, whole genome shotgun sequence
# CAJCMC010000173 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig173, whole genome shotgun sequence
# CAJCMC010000174 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig174, whole genome shotgun sequence
# CAJCMC010000175 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig175, whole genome shotgun sequence
# CAJCMC010000176 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig176, whole genome shotgun sequence
# CAJCMC010000177 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig177, whole genome shotgun sequence
# CAJCMC010000178 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig178, whole genome shotgun sequence
# CAJCMC010000179 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig179, whole genome shotgun sequence
# CAJCMC010000180 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig180, whole genome shotgun sequence
# CAJCMC010000181 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig181, whole genome shotgun sequence
# CAJCMC010000182 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig182, whole genome shotgun sequence
# CAJCMC010000183 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig183, whole genome shotgun sequence
# CAJCMC010000184 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig184, whole genome shotgun sequence
# CAJCMC010000185 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig185, whole genome shotgun sequence
# CAJCMC010000186 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig186, whole genome shotgun sequence
# CAJCMC010000187 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig187, whole genome shotgun sequence
# CAJCMC010000188 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig188, whole genome shotgun sequence
# CAJCMC010000189 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig189, whole genome shotgun sequence
# CAJCMC010000190 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig190, whole genome shotgun sequence
# CAJCMC010000191 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig191, whole genome shotgun sequence
# CAJCMC010000192 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig192, whole genome shotgun sequence
# CAJCMC010000193 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig193, whole genome shotgun sequence
# CAJCMC010000194 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig194, whole genome shotgun sequence
# CAJCMC010000195 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig195, whole genome shotgun sequence
# CAJCMC010000196 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig196, whole genome shotgun sequence
# CAJCMC010000197 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig197, whole genome shotgun sequence
# CAJCMC010000198 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig198, whole genome shotgun sequence
# CAJCMC010000199 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig199, whole genome shotgun sequence
# CAJCMC010000200 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig200, whole genome shotgun sequence
# CAJCMC010000201 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig201, whole genome shotgun sequence
# CAJCMC010000202 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig202, whole genome shotgun sequence
# CAJCMC010000203 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig203, whole genome shotgun sequence
# CAJCMC010000204 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig204, whole genome shotgun sequence
# CAJCMC010000205 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig205, whole genome shotgun sequence
# CAJCMC010000206 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig206, whole genome shotgun sequence
# CAJCMC010000207 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig207, whole genome shotgun sequence
# CAJCMC010000208 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig208, whole genome shotgun sequence
# CAJCMC010000209 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig209, whole genome shotgun sequence
# CAJCMC010000210 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig210, whole genome shotgun sequence
# CAJCMC010000211 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig211, whole genome shotgun sequence
# CAJCMC010000212 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig212, whole genome shotgun sequence
# CAJCMC010000213 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig213, whole genome shotgun sequence
# CAJCMC010000214 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig214, whole genome shotgun sequence
# CAJCMC010000215 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig215, whole genome shotgun sequence
# CAJCMC010000216 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig216, whole genome shotgun sequence
# CAJCMC010000217 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig217, whole genome shotgun sequence
# CAJCMC010000218 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig218, whole genome shotgun sequence
# CAJCMC010000219 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig219, whole genome shotgun sequence
# CAJCMC010000220 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig220, whole genome shotgun sequence
# CAJCMC010000221 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig221, whole genome shotgun sequence
# CAJCMC010000222 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig222, whole genome shotgun sequence
# CAJCMC010000223 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig223, whole genome shotgun sequence
# CAJCMC010000224 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig224, whole genome shotgun sequence
# CAJCMC010000225 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig225, whole genome shotgun sequence
# CAJCMC010000226 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig226, whole genome shotgun sequence
# CAJCMC010000227 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig227, whole genome shotgun sequence
# CAJCMC010000228 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig228, whole genome shotgun sequence
# CAJCMC010000229 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig229, whole genome shotgun sequence
# CAJCMC010000230 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig230, whole genome shotgun sequence
# CAJCMC010000231 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig231, whole genome shotgun sequence
# CAJCMC010000232 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig232, whole genome shotgun sequence
# CAJCMC010000233 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig233, whole genome shotgun sequence
# CAJCMC010000234 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig234, whole genome shotgun sequence
# CAJCMC010000235 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig235, whole genome shotgun sequence
# CAJCMC010000236 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig236, whole genome shotgun sequence
# CAJCMC010000237 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig237, whole genome shotgun sequence
# CAJCMC010000238 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig238, whole genome shotgun sequence
# CAJCMC010000239 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig239, whole genome shotgun sequence
# CAJCMC010000240 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig240, whole genome shotgun sequence
# CAJCMC010000241 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig241, whole genome shotgun sequence
# CAJCMC010000242 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig242, whole genome shotgun sequence
# CAJCMC010000243 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig243, whole genome shotgun sequence
# CAJCMC010000244 | Escherichia coli isolate 001-031-c1 genome assembly, contig: 001-031-c1_contig244, whole genome shotgun sequence

# %% [markdown]
# Do not mix isolates and accession number.

# %%
def search_ncbi_universal_simple(identifier, db="nucleotide", verbose=True):
    """
    Simplified universal NCBI search without pre-classification.
    """
    if verbose:
        print(f"Searching NCBI '{db}' database for: {identifier}")
    
    # Strategy 1: Direct search (works for most cases)
    try:
        handle = Entrez.esearch(db=db, term=identifier, retmax=10)
        results = Entrez.read(handle)
        handle.close()
        
        ids = results.get("IdList", [])
        if ids:
            if verbose:
                print(f"  Found {len(ids)} record(s) with direct search")
            return ids
    except Exception as e:
        if verbose:
            print(f"  Direct search failed: {e}")
    
    # Strategy 2: Accession field search
    try:
        handle = Entrez.esearch(db=db, term=f"{identifier}[Accession]", retmax=10)
        results = Entrez.read(handle)
        handle.close()
        
        ids = results.get("IdList", [])
        if ids:
            if verbose:
                print(f"  Found {len(ids)} record(s) with accession field search")
            return ids
    except Exception as e:
        if verbose:
            print(f"  Accession field search failed: {e}")
    
    # Strategy 3: Try isolate/strain searches for everything
    isolate_strategies = [
        f'"{identifier}"[Isolate]',
        f'"{identifier}"[Strain]',
        f'"{identifier}"[All Fields]'
    ]
    
    for strategy in isolate_strategies:
        try:
            handle = Entrez.esearch(db=db, term=strategy, retmax=100)
            results = Entrez.read(handle)
            handle.close()
            
            ids = results.get("IdList", [])
            if ids:
                if verbose:
                    print(f"  Found {len(ids)} record(s) with strategy: {strategy}")
                return ids
        except Exception as e:
            if verbose:
                print(f"  Strategy '{strategy}' failed: {e}")
            continue
    
    if verbose:
        print(f"  No records found for {identifier}")
    return []

# %%
from xml.etree import ElementTree
import re
import time
import pandas as pd

# Replace with your email — required by NCBI
Entrez.email = "your.email@example.com"

def search_ncbi_universal_simple(identifier, db="nucleotide", verbose=True):
    """
    Simplified universal NCBI search without pre-classification.
    """
    if verbose:
        print(f"Searching NCBI '{db}' database for: {identifier}")
    
    # Strategy 1: Direct search (works for most cases)
    try:
        handle = Entrez.esearch(db=db, term=identifier, retmax=10)
        results = Entrez.read(handle)
        handle.close()
        
        ids = results.get("IdList", [])
        if ids:
            if verbose:
                print(f"  Found {len(ids)} record(s) with direct search")
            return ids
    except Exception as e:
        if verbose:
            print(f"  Direct search failed: {e}")
    
    # Strategy 2: Accession field search
    try:
        handle = Entrez.esearch(db=db, term=f"{identifier}[Accession]", retmax=10)
        results = Entrez.read(handle)
        handle.close()
        
        ids = results.get("IdList", [])
        if ids:
            if verbose:
                print(f"  Found {len(ids)} record(s) with accession field search")
            return ids
    except Exception as e:
        if verbose:
            print(f"  Accession field search failed: {e}")
    
    # Strategy 3: Try isolate/strain searches for everything
    isolate_strategies = [
        f'"{identifier}"[Isolate]',
        f'"{identifier}"[Strain]',
        f'"{identifier}"[All Fields]'
    ]
    
    for strategy in isolate_strategies:
        try:
            handle = Entrez.esearch(db=db, term=strategy, retmax=100)
            results = Entrez.read(handle)
            handle.close()
            
            ids = results.get("IdList", [])
            if ids:
                if verbose:
                    print(f"  Found {len(ids)} record(s) with strategy: {strategy}")
                return ids
        except Exception as e:
            if verbose:
                print(f"  Strategy '{strategy}' failed: {e}")
            continue
    
    if verbose:
        print(f"  No records found for {identifier}")
    return []

def fetch_summary(ids, db="nucleotide", verbose=True):
    """
    Fetch summaries (titles, accession numbers, etc.) for given NCBI IDs.
    """
    if not ids:
        return []

    handle = Entrez.esummary(db=db, id=",".join(ids))
    records = Entrez.read(handle)
    handle.close()

    if verbose:
        for record in records:
            print(f"{record['Caption']} | {record['Title']}")

    return records

def group_sequences_by_criteria(summaries):
    """Group sequences by various criteria."""
    grouped_data = {
        'by_organism': {},
        'by_length': {'short': [], 'medium': [], 'long': []},
        'by_type': {'complete': [], 'draft': [], 'contig': []},
        'by_source': {}
    }
    
    for record in summaries:
        # Group by organism
        organism = record.get('Organism', 'Unknown')
        if organism not in grouped_data['by_organism']:
            grouped_data['by_organism'][organism] = []
        grouped_data['by_organism'][organism].append(record)
        
        # Group by sequence length
        length = int(record.get('Length', 0))
        if length < 10000:
            grouped_data['by_length']['short'].append(record)
        elif length < 100000:
            grouped_data['by_length']['medium'].append(record)
        else:
            grouped_data['by_length']['long'].append(record)
        
        # Group by sequence type
        title = record.get('Title', '').lower()
        if 'complete' in title:
            grouped_data['by_type']['complete'].append(record)
        elif 'draft' in title:
            grouped_data['by_type']['draft'].append(record)
        else:
            grouped_data['by_type']['contig'].append(record)
        
        # Group by source/submitter
        authors = record.get('Authors', 'Unknown')
        if authors not in grouped_data['by_source']:
            grouped_data['by_source'][authors] = []
        grouped_data['by_source'][authors].append(record)
    
    return grouped_data

def create_summary_dataframe(grouped_data):
    """Create a summary DataFrame from grouped data."""
    summary_list = []
    
    for record in grouped_data.get('all_records', []):
        summary_list.append({
            'accession': record.get('Caption', ''),
            'title': record.get('Title', ''),
            'organism': record.get('Organism', ''),
            'length': int(record.get('Length', 0)),
            'authors': record.get('Authors', ''),
            'create_date': record.get('CreateDate', ''),
            'update_date': record.get('UpdateDate', '')
        })
    
    return pd.DataFrame(summary_list)

def comprehensive_sequence_search_all(isolate_list, output_file=None):
    """
    Search all identifiers and return comprehensive results.
    """
    results = {}
    
    for i, isolate in enumerate(isolate_list):
        print(f"Processing identifier {i+1}/{len(isolate_list)}: {isolate}")
        
        # Add delay to respect NCBI rate limits
        if i > 0:
            time.sleep(0.5)
        
        # Use universal search
        ids = search_ncbi_universal_simple(isolate, verbose=False)
        
        if ids:
            summaries = fetch_summary(ids, verbose=False)
            if summaries:
                grouped = group_sequences_by_criteria(summaries)
                grouped['all_records'] = summaries
                
                results[isolate] = {
                    'total_sequences': len(ids),
                    'ids': ids,
                    'grouped_data': grouped,
                    'dataframe': create_summary_dataframe(grouped)
                }
                
                # Print brief summary
                print(f"  ✓ Found {len(ids)} sequence(s)")
                if summaries:
                    print(f"    Example: {summaries[0]['Caption']} | {summaries[0]['Title'][:60]}...")
            else:
                results[isolate] = {'total_sequences': 0, 'ids': []}
        else:
            results[isolate] = {'total_sequences': 0, 'ids': []}
            print(f"  ✗ No sequences found")
    
    return results

# Extract identifiers from virus and host dataframes
print("Extracting identifiers from VHRdb data...")

# Get virus identifiers with NCBI IDs
virus_ncbi_identifiers = VHRdb_virus_df[
    (VHRdb_virus_df["is_ncbi_identifier_value"] == True) & 
    (VHRdb_virus_df["identifier"].notna())
]["identifier"].tolist()

# Get host identifiers with NCBI IDs
host_ncbi_identifiers = VHRdb_host_df[
    (VHRdb_host_df["is_ncbi_identifier_value"] == True) & 
    (VHRdb_host_df["identifier"].notna())
]["identifier"].tolist()

print(f"Found {len(virus_ncbi_identifiers)} virus identifiers with NCBI")
print(f"Found {len(host_ncbi_identifiers)} host identifiers with NCBI")

# Combine all NCBI identifiers
all_ncbi_identifiers = virus_ncbi_identifiers + host_ncbi_identifiers
print(f"Total NCBI identifiers to search: {len(all_ncbi_identifiers)}")

# Remove duplicates if any
all_ncbi_identifiers = list(set(all_ncbi_identifiers))
print(f"Unique NCBI identifiers: {len(all_ncbi_identifiers)}")

print("\n" + "="*70)
print("Starting comprehensive search for all NCBI identifiers:")
print("="*70)

# Run the search on all identifiers
results_all = comprehensive_sequence_search_all(all_ncbi_identifiers)

# Create summary statistics
print("\n" + "="*50)
print("FINAL SUMMARY:")
print("="*50)

successful = sum(1 for data in results_all.values() if data['total_sequences'] > 0)
total = len(results_all)
total_sequences = sum(data['total_sequences'] for data in results_all.values())

print(f"Success rate: {successful}/{total} ({successful/total*100:.1f}%)")
print(f"Total sequences found: {total_sequences}")
print(f"Average sequences per successful identifier: {total_sequences/successful if successful > 0 else 0:.1f}")

# Detailed breakdown
print("\nDetailed results:")
sequence_counts = []
for isolate, data in results_all.items():
    status = "✓" if data['total_sequences'] > 0 else "✗"
    print(f"{status} {isolate}: {data['total_sequences']} sequences")
    if data['total_sequences'] > 0:
        sequence_counts.append(data['total_sequences'])

# Create summary DataFrame
summary_df = pd.DataFrame([
    {
        'identifier': isolate,
        'found': data['total_sequences'] > 0,
        'num_sequences': data['total_sequences']
    }
    for isolate, data in results_all.items()
])

if sequence_counts:
    print(f"\nSequence count distribution:")
    print(f"Min sequences: {min(sequence_counts)}")
    print(f"Max sequences: {max(sequence_counts)}")
    print(f"Median sequences: {np.median(sequence_counts)}")

# Store results for further analysis
search_results = results_all
search_summary = summary_df

print(f"\nResults stored in variables:")
print(f"- search_results: detailed results dictionary")
print(f"- search_summary: summary DataFrame")
# Out:
# Extracting identifiers from VHRdb data...
# Found 316 virus identifiers with NCBI
# Found 28 host identifiers with NCBI
# Total NCBI identifiers to search: 344
# Unique NCBI identifiers: 340
#
# ======================================================================
# Starting comprehensive search for all NCBI identifiers:
# ======================================================================
# Processing identifier 1/340: DQ838728
#   ✓ Found 1 sequence(s)
#     Example: DQ838728 | Lactococcus phage P335, complete genome...
# Processing identifier 2/340: NC_019446
#   ✓ Found 1 sequence(s)
#     Example: NC_019446 | Brucella phage Tb, complete genome...
# Processing identifier 3/340: HG962376
#   ✓ Found 1 sequence(s)
#     Example: HG962376 | Pseudomonas phage vB_PaeS_SCH_Ab26, complete genome...
# Processing identifier 4/340: MT354569
#   ✓ Found 1 sequence(s)
#     Example: MT354569 | Pseudomonas phage phiK7B1, complete genome...
# Processing identifier 5/340: CP003316
#   ✓ Found 1 sequence(s)
#     Example: CP003316 | Pyrobaculum oguniense TE7, complete genome...
# Processing identifier 6/340: KY290954
#   ✓ Found 1 sequence(s)
#     Example: KY290954 | Aeromonas phage 56, complete genome...
# Processing identifier 7/340: KP869111
#   ✓ Found 1 sequence(s)
#     Example: KP869111 | Escherichia coli O157 typing phage 13, partial genome...
# Processing identifier 8/340: NC_015719
#   ✓ Found 1 sequence(s)
#     Example: NC_015719 | Enterobacteria phage K30, complete genome...
# Processing identifier 9/340: LN610583
#   ✓ Found 1 sequence(s)
#     Example: LN610583 | Pseudomonas phage vB_PaeM_PAO1_Ab11, complete genome...
# Processing identifier 10/340: NC_028962
#   ✓ Found 1 sequence(s)
#     Example: NC_028962 | Staphylococcus phage phiIPLA-C1C, complete genome...
# Processing identifier 11/340: NC_023693
#   ✓ Found 1 sequence(s)
#     Example: NC_023693 | Enterobacteria phage phi92, complete genome...
# Processing identifier 12/340: NC_031031
#   ✓ Found 1 sequence(s)
#     Example: NC_031031 | Gordonia phage Remus, complete genome...
# Processing identifier 13/340: NC_028958
#   ✓ Found 1 sequence(s)
#     Example: NC_028958 | Clostridium phage phiCD146, complete genome...
# Processing identifier 14/340: NC_026600
#   ✓ Found 1 sequence(s)
#     Example: NC_026600 | Pseudomonas phage vB_PaeM_C1-14_Ab28, complete genome...
# Processing identifier 15/340: NC_002167
#   ✓ Found 1 sequence(s)
#     Example: NC_002167 | Enterobacteria phage HK97, complete genome...
# Processing identifier 16/340: NC_004086
#   ✓ Found 1 sequence(s)
#     Example: NC_004086 | Sulfolobus islandicus rod-shaped virus 2, complete genome...
# Processing identifier 17/340: KU998234
#   ✓ Found 1 sequence(s)
#     Example: KU998234 | Gordonia phage Wizard, complete genome...
# Processing identifier 18/340: KU963263
#   ✓ Found 1 sequence(s)
#     Example: KU963263 | Gordonia phage BaxterFox, complete genome...
# Processing identifier 19/340: JX997166.1
#   ✓ Found 1 sequence(s)
#     Example: JX997166 | Paramecium bursaria Chlorella virus CZ-2, partial genome...
# Processing identifier 20/340: NC_012663
#   ✓ Found 1 sequence(s)
#     Example: NC_012663 | Lactococcus phage P087, complete genome...
# Processing identifier 21/340: NC_012884
#   ✓ Found 1 sequence(s)
#     Example: NC_012884 | Streptococcus phage M102, complete genome...
# Processing identifier 22/340: KP869103
#   ✓ Found 1 sequence(s)
#     Example: KP869103 | Escherichia coli O157 typing phage 5, complete genome...
# Processing identifier 23/340: KR935213
#   ✓ Found 1 sequence(s)
#     Example: KR935213 | Rhodobacter phage RcTitan, complete genome...
# Processing identifier 24/340: MZ348426
#   ✓ Found 1 sequence(s)
#     Example: MZ348426 | Pseudomonas phage psageK4, complete genome...
# Processing identifier 25/340: MZ348425
#   ✓ Found 1 sequence(s)
#     Example: MZ348425 | Pseudomonas phage psageB2, complete genome...
# Processing identifier 26/340: NC_013697
#   ✓ Found 1 sequence(s)
#     Example: NC_013697 | Delftia phage PhiW-14, complete genome...
# Processing identifier 27/340: NC_008364
#   ✓ Found 1 sequence(s)
#     Example: NC_008364 | Lactococcus phage Q54, complete genome...
# Processing identifier 28/340: NC_018750.1
#   ✓ Found 1 sequence(s)
#     Example: NC_018750 | Streptomyces venezuelae ATCC 10712, complete sequence...
# Processing identifier 29/340: MT496971
#   ✓ Found 1 sequence(s)
#     Example: MT496971 | Escherichia phage Mt1B1_P10, complete genome...
# Processing identifier 30/340: LR657304.1
#   ✓ Found 1 sequence(s)
#     Example: LR657304 | Pseudomonas aeruginosa strain PAK genome assembly, chromosom...
# Processing identifier 31/340: OL770107
#   ✓ Found 1 sequence(s)
#     Example: OL770107 | Escherichia phage CLB_P2, complete genome...
# Processing identifier 32/340: NC_027120
#   ✓ Found 1 sequence(s)
#     Example: NC_027120 | Lactococcus phage 1358, complete sequence...
# Processing identifier 33/340: EU863408
#   ✓ Found 1 sequence(s)
#     Example: EU863408 | Enterobacteria phage JSE, complete genome...
# Processing identifier 34/340: NC_007059
#   ✓ Found 1 sequence(s)
#     Example: NC_007059 | Staphylococcus phage 71, complete genome...
# Processing identifier 35/340: JX997156.1
#   ✓ Found 1 sequence(s)
#     Example: JX997156 | Acanthocystis turfacea Chlorella virus Can0610SP, partial ge...
# Processing identifier 36/340: NC_028984
#   ✓ Found 1 sequence(s)
#     Example: NC_028984 | Streptococcus phage M102AD, complete genome...
# Processing identifier 37/340: JX997173.1
#   ✓ Found 1 sequence(s)
#     Example: JX997173 | Paramecium bursaria Chlorella virus MA-1E, partial genome...
# Processing identifier 38/340: NC_000913.3
#   ✓ Found 1 sequence(s)
#     Example: NC_000913 | Escherichia coli str. K-12 substr. MG1655, complete genome...
# Processing identifier 39/340: NC_005178
#   ✓ Found 1 sequence(s)
#     Example: NC_005178 | Bacteriophage D3112, complete genome...
# Processing identifier 40/340: NC_013645
#   ✓ Found 1 sequence(s)
#     Example: NC_013645 | Streptococcus phage Abc2, complete genome...
# Processing identifier 41/340: NC_002703
#   ✓ Found 1 sequence(s)
#     Example: NC_002703 | Lactococcus phage Tuc2009, complete genome...
# Processing identifier 42/340: KP869112
#   ✓ Found 1 sequence(s)
#     Example: KP869112 | Escherichia coli O157 typing phage 14, partial genome...
# Processing identifier 43/340: KY290955
#   ✓ Found 1 sequence(s)
#     Example: KY290955 | Aeromonas phage 65.2, complete genome...
# Processing identifier 44/340: JX997176.1
#   ✓ Found 1 sequence(s)
#     Example: JX997176 | Paramecium bursaria Chlorella virus NE-JV-1, partial genome...
# Processing identifier 45/340: NC_024140
#   ✓ Found 1 sequence(s)
#     Example: NC_024140 | Pseudomonas phage vB_PaeP_C2-10_Ab09, complete genome...
# Processing identifier 46/340: NC_010325
#   ✓ Found 1 sequence(s)
#     Example: NC_010325 | Pseudomonas phage LUZ24, complete genome...
# Processing identifier 47/340: NC_002484
#   ✓ Found 1 sequence(s)
#     Example: NC_002484 | Bacteriophage D3, complete genome...
# Processing identifier 48/340: JX997181.1
#   ✓ Found 1 sequence(s)
#     Example: JX997181 | Paramecium bursaria Chlorella virus NW665.2, partial genome...
# Processing identifier 49/340: JX997175.1
#   ✓ Found 1 sequence(s)
#     Example: JX997175 | Acanthocystis turfacea Chlorella virus MO0605SPH, partial ge...
# Processing identifier 50/340: ADIC00000000.1
#   ✓ Found 1 sequence(s)
#     Example: ADIC00000000 | Chlorella variabilis strain NC64A, whole genome shotgun sequ...
# Processing identifier 51/340: NC_019422
#   ✓ Found 1 sequence(s)
#     Example: NC_019422 | Clostridium phage phiMMP04, complete genome...
# Processing identifier 52/340: OV696619
#   ✓ Found 1 sequence(s)
#     Example: OV696619 | Glutamicibacter phage Montesquieu genome assembly, complete ...
# Processing identifier 53/340: NC_029080
#   ✓ Found 1 sequence(s)
#     Example: NC_029080 | Staphylococcus phage 812, complete genome...
# Processing identifier 54/340: NC_002649
#   ✓ Found 1 sequence(s)
#     Example: NC_002649 | Bacillus phage GA-1, complete genome...
# Processing identifier 55/340: JX997170.1
#   ✓ Found 1 sequence(s)
#     Example: JX997170 | Paramecium bursaria Chlorella virus IL-5-2s1, partial genome...
# Processing identifier 56/340: NC_021788
#   ✓ Found 1 sequence(s)
#     Example: NC_021788 | Cellulophaga phage phi4:1, complete genome...
# Processing identifier 57/340: KU998244
#   ✓ Found 1 sequence(s)
#     Example: KU998244 | Gordonia phage Smoothie, complete genome...
# Processing identifier 58/340: KY290948
#   ✓ Found 1 sequence(s)
#     Example: KY290948 | Aeromonas phage 44RR2.8t.2, complete genome...
# Processing identifier 59/340: KY290953
#   ✓ Found 1 sequence(s)
#     Example: KY290953 | Aeromonas phage 51, complete genome...
# Processing identifier 60/340: MN876842
#   ✓ Found 1 sequence(s)
#     Example: MN876842 | Acidianus rod-shaped virus 3 isolate 9, complete genome...
# Processing identifier 61/340: LN610582
#   ✓ Found 1 sequence(s)
#     Example: LN610582 | Pseudomonas phage vB_PaeM_PAO1_Ab06, complete genome...
# Processing identifier 62/340: KU998237
#   ✓ Found 1 sequence(s)
#     Example: KU998237 | Gordonia phage Vendetta, complete genome...
# Processing identifier 63/340: NC_015518
#   ✓ Found 1 sequence(s)
#     Example: NC_015518 | Acidianus hospitalis W1, complete sequence...
# Processing identifier 64/340: LN610578
#   ✓ Found 1 sequence(s)
#     Example: LN610578 | Pseudomonas phage vB_PaeP_C2-10_Ab22, complete genome...
# Processing identifier 65/340: NC_022966
#   ✓ Found 1 sequence(s)
#     Example: NC_022966 | Pseudomonas phage PAK_P5, complete genome...
# Processing identifier 66/340: LN610576
#   ✓ Found 1 sequence(s)
#     Example: LN610576 | Pseudomonas phage vB_PaeM_PAO1_Ab17, complete genome...
# Processing identifier 67/340: NC_007047
#   ✓ Found 1 sequence(s)
#     Example: NC_007047 | Staphylococcus phage 187, complete genome...
# Processing identifier 68/340: JX997158.1
#   ✓ Found 1 sequence(s)
#     Example: JX997158 | Acanthocystis turfacea Chlorella virus Canal-1, partial geno...
# Processing identifier 69/340: JX997169.1
#   ✓ Found 1 sequence(s)
#     Example: JX997169 | Paramecium bursaria Chlorella virus IL-3A, partial genome...
# Processing identifier 70/340: NC_005948
#   ✓ Found 1 sequence(s)
#     Example: NC_005948 | Vibrio phage Vf33, complete genome...
# Processing identifier 71/340: KJ617393
#   ✓ Found 1 sequence(s)
#     Example: KJ617393 | Streptococcus phage SOCP, complete genome...
# Processing identifier 72/340: AY441783
#   ✓ Found 1 sequence(s)
#     Example: AY441783 | Bacteriophage PR772, complete genome...
# Processing identifier 73/340: NZ_CP028714.1
#   ✓ Found 1 sequence(s)
#     Example: NZ_CP028714 | Escherichia coli strain Mt1B1 chromosome...
# Processing identifier 74/340: MZ868717
#   ✓ Found 1 sequence(s)
#     Example: MZ868717 | Pseudomonas phage pphageBV72, complete genome...
# Processing identifier 75/340: DQ529280
#   ✓ Found 1 sequence(s)
#     Example: DQ529280 | Aeromonas phage 25, complete genome...
# Processing identifier 76/340: MT711976
#   ✓ Found 1 sequence(s)
#     Example: MT711976 | Streptomyces phage Coruscant, complete genome...
# Processing identifier 77/340: JX997186.1
#   ✓ Found 1 sequence(s)
#     Example: JX997186 | Acanthocystis turfacea Chlorella virus TN603.4.2, partial ge...
# Processing identifier 78/340: NC_008584
#   ✓ Found 1 sequence(s)
#     Example: NC_008584 | Thermus phage phiYS40, complete genome...
# Processing identifier 79/340: NC_014660
#   ✓ Found 1 sequence(s)
#     Example: NC_014660 | Acinetobacter phage Ac42, complete genome...
# Processing identifier 80/340: NC_002700
#   ✓ Found 1 sequence(s)
#     Example: NC_002700 | Acinetobacter phage AP205, complete genome...
# Processing identifier 81/340: NC_042115
#   ✓ Found 1 sequence(s)
#     Example: NC_042115 | Pseudomonas phage vB_PaeS_PAO1_Ab19, complete genome...
# Processing identifier 82/340: NC_032001.1
#   ✓ Found 1 sequence(s)
#     Example: NC_032001 | Only Syngen Nebraska virus 5, complete genome...
# Processing identifier 83/340: MT711975
#   ✓ Found 1 sequence(s)
#     Example: MT711975 | Streptomyces phage Alderaan, complete genome...
# Processing identifier 84/340: KY290951
#   ✓ Found 1 sequence(s)
#     Example: KY290951 | Aeromonas phage 31.2, complete genome...
# Processing identifier 85/340: JX997157.1
#   ✓ Found 1 sequence(s)
#     Example: JX997157 | Paramecium bursaria Chlorella virus Can18-4, partial genome...
# Processing identifier 86/340: NC_002072
#   ✓ Found 1 sequence(s)
#     Example: NC_002072 | Streptococcus phage DT1, complete genome...
# Processing identifier 87/340: GQ979703
#   ✓ Found 1 sequence(s)
#     Example: GQ979703 | Lactococcus lactis phage p2, complete genome...
# Processing identifier 88/340: MT711977
#   ✓ Found 1 sequence(s)
#     Example: MT711977 | Streptomyces phage Dagobah, complete genome...
# Processing identifier 89/340: EU863409
#   ✓ Found 1 sequence(s)
#     Example: EU863409 | Enterobacteria phage JS10, complete sequence...
# Processing identifier 90/340: NC_001909
#   ✓ Found 1 sequence(s)
#     Example: NC_001909 | Lactococcus phage bIL170, complete genome...
# Processing identifier 91/340: KC556896
#   ✓ Found 1 sequence(s)
#     Example: KC556896 | Brucella phage S708, complete genome...
# Processing identifier 92/340: EF108465
#   ✓ Found 1 sequence(s)
#     Example: EF108465 | Enterobacteria phage MS2 isolate R17, complete genome...
# Processing identifier 93/340: NC_020416
#   ✓ Found 1 sequence(s)
#     Example: NC_020416 | Salmonella phage S16, complete genome...
# Processing identifier 94/340: JX997164.1
#   ✓ Found 1 sequence(s)
#     Example: JX997164 | Paramecium bursaria Chlorella virus CVR-1, partial genome...
# Processing identifier 95/340: NC_001331
#   ✓ Found 1 sequence(s)
#     Example: NC_001331 | Pseudomonas phage Pf1, complete genome...
# Processing identifier 96/340: NC_000866.4
#   ✓ Found 1 sequence(s)
#     Example: NC_000866 | Enterobacteria phage T4, complete genome...
# Processing identifier 97/340: NC_001628
#   ✓ Found 1 sequence(s)
#     Example: NC_001628 | Pseudomonas phage PP7, complete genome...
# Processing identifier 98/340: NC_028764
#   ✓ Found 1 sequence(s)
#     Example: NC_028764 | Clostridium phage phiCD505, complete genome...
# Processing identifier 99/340: JX997162.1
#   ✓ Found 1 sequence(s)
#     Example: JX997162 | Paramecium bursaria Chlorella virus CviKI, partial genome...
# Processing identifier 100/340: NC_028888
#   ✓ Found 1 sequence(s)
#     Example: NC_028888 | Lactobacillus phage CL1, complete genome...
# Processing identifier 101/340: NC_013598
#   ✓ Found 1 sequence(s)
#     Example: NC_013598 | Streptococcus phage ALQ13.2, complete genome...
# Processing identifier 102/340: LT594787
#   ✓ Found 1 sequence(s)
#     Example: LT594787 | Pseudomonas aeruginosa isolate ph_P3P1 genome assembly, chro...
# Processing identifier 103/340: MZ868714
#   ✓ Found 1 sequence(s)
#     Example: MZ868714 | Pseudomonas phage pphageB21, complete genome...
# Processing identifier 104/340: NC_022757
#   ✓ Found 1 sequence(s)
#     Example: NC_022757 | Lactobacillus phage PL-1, complete genome...
# Processing identifier 105/340: KC862296
#   ✓ Found 1 sequence(s)
#     Example: KC862296 | Pseudomonas phage P3_CHA, complete genome...
# Processing identifier 106/340: NC_015568
#   ✓ Found 1 sequence(s)
#     Example: NC_015568 | Clostridium phage phiCD38-2, complete genome...
# Processing identifier 107/340: KP869108
#   ✓ Found 1 sequence(s)
#     Example: KP869108 | Escherichia coli O157 typing phage 10, complete genome...
# Processing identifier 108/340: CP009273.1
#   ✓ Found 1 sequence(s)
#     Example: CP009273 | Escherichia coli BW25113, complete genome...
# Processing identifier 109/340: NC_011048
#   ✓ Found 1 sequence(s)
#     Example: NC_011048 | Bacillus phage phi29, complete genome...
# Processing identifier 110/340: KP869110
#   ✓ Found 1 sequence(s)
#     Example: KP869110 | Escherichia coli O157 typing phage 12, complete genome...
# Processing identifier 111/340: DQ163912
#   ✓ Found 1 sequence(s)
#     Example: DQ163912 | Bacteriophage F10, complete genome...
# Processing identifier 112/340: NC_019813
#   ✓ Found 1 sequence(s)
#     Example: NC_019813 | Pseudomonas phage vB_PaeP_p2-10_Or1, complete genome...
# Processing identifier 113/340: NC_023719
#   ✓ Found 1 sequence(s)
#     Example: NC_023719 | Bacillus phage G, complete genome...
# Processing identifier 114/340: DQ491001.1
#   ✓ Found 1 sequence(s)
#     Example: DQ491001 | Paramecium bursaria chlorella virus MT325 genomic sequence...
# Processing identifier 115/340: NC_030884
#   ✓ Found 1 sequence(s)
#     Example: NC_030884 | Sulfolobus islandicus rudivirus 3 isolate SIRV3, complete ge...
# Processing identifier 116/340: NZ_LN874954.1
#   ✓ Found 1 sequence(s)
#     Example: NZ_LN874954 | Escherichia coli strain LM33 isolate patient, whole genome s...
# Processing identifier 117/340: DQ163917
#   ✓ Found 1 sequence(s)
#     Example: DQ163917 | Bacteriophage F8, complete genome...
# Processing identifier 118/340: NC_026602
#   ✓ Found 1 sequence(s)
#     Example: NC_026602 | Pseudomonas phage vB_PaeP_PAO1_Ab05, complete genome...
# Processing identifier 119/340: NC_038017
#   ✓ Found 1 sequence(s)
#     Example: NC_038017 | Sulfolobus polyhedral virus 1 isolate S14, complete genome...
# Processing identifier 120/340: NC_002754
#   ✓ Found 1 sequence(s)
#     Example: NC_002754 | Saccharolobus solfataricus P2, complete sequence...
# Processing identifier 121/340: NC_002371
#   ✓ Found 1 sequence(s)
#     Example: NC_002371 | Salmonella phage P22, complete genome...
# Processing identifier 122/340: NC_022967
#   ✓ Found 1 sequence(s)
#     Example: NC_022967 | Pseudomonas phage PAK_P2, complete genome...
# Processing identifier 123/340: NC_026594
#   ✓ Found 1 sequence(s)
#     Example: NC_026594 | Pseudomonas phage vB_PaeS_PAO1_Ab18, complete genome...
# Processing identifier 124/340: JX997185.1
#   ✓ Found 1 sequence(s)
#     Example: JX997185 | Acanthocystis turfacea Chlorella virus OR0704.3, partial gen...
# Processing identifier 125/340: LN610588
#   ✓ Found 1 sequence(s)
#     Example: LN610588 | Pseudomonas phage vB_PaeM_PAO1_Ab29, complete genome...
# Processing identifier 126/340: LT717094
#   ✓ Found 1 sequence(s)
#     Example: LT717094 | Escherichia coli strain LF82_P10 genome assembly, chromosome...
# Processing identifier 127/340: NC_026587
#   ✓ Found 1 sequence(s)
#     Example: NC_026587 | Pseudomonas phage vB_PaeM_PAO1_Ab03, complete genome...
# Processing identifier 128/340: LT821717
#   ✓ Found 1 sequence(s)
#     Example: LT821717 | LeviOr01 virus genome assembly, chromosome: LeviOr01...
# Processing identifier 129/340: NC_019918
#   ✓ Found 1 sequence(s)
#     Example: NC_019918 | Pseudomonas phage vB_PaeM_C2-10_Ab1 complete genome...
# Processing identifier 130/340: KY579375
#   ✓ Found 1 sequence(s)
#     Example: KY579375 | Sulfolobus spindle-shaped virus 3 strain REY 15/4, complete ...
# Processing identifier 131/340: NC_026601
#   ✓ Found 1 sequence(s)
#     Example: NC_026601 | Pseudomonas phage vB_PaeS_PAO1_Ab30, complete genome...
# Processing identifier 132/340: MT711979
#   ✓ Found 1 sequence(s)
#     Example: MT711979 | Streptomyces phage Endor2, complete genome...
# Processing identifier 133/340: NC_029548
#   ✓ Found 1 sequence(s)
#     Example: NC_029548 | Pyrobaculum filamentous virus 1, complete genome...
# Processing identifier 134/340: NC_001895
#   ✓ Found 1 sequence(s)
#     Example: NC_001895 | Enterobacteria phage P2, complete genome...
# Processing identifier 135/340: KU963247
#   ✓ Found 1 sequence(s)
#     Example: KU963247 | Gordonia phage Attis, complete genome...
# Processing identifier 136/340: JX997171.1
#   ✓ Found 1 sequence(s)
#     Example: JX997171 | Paramecium bursaria Chlorella virus KS1B, partial genome...
# Processing identifier 137/340: NC_028838
#   ✓ Found 1 sequence(s)
#     Example: NC_028838 | Clostridium phage phiCD506, complete genome...
# Processing identifier 138/340: MT354570
#   ✓ Found 1 sequence(s)
#     Example: MT354570 | Pseudomonas phage phiB1_1, complete genome...
# Processing identifier 139/340: NC_025422
#   ✓ Found 1 sequence(s)
#     Example: NC_025422 | Caulobacter phage Cr30, complete genome...
# Processing identifier 140/340: OV696621
#   ✓ Found 1 sequence(s)
#     Example: OV696621 | Leuconostoc phage Diderot genome assembly, complete genome: ...
# Processing identifier 141/340: NC_007019
#   ✓ Found 1 sequence(s)
#     Example: NC_007019 | Streptococcus phage 2972, complete genome...
# Processing identifier 142/340: JX997167.1
#   ✓ Found 1 sequence(s)
#     Example: JX997167 | Paramecium bursaria Chlorella virus Fr5L, partial genome...
# Processing identifier 143/340: NC_004166
#   ✓ Found 1 sequence(s)
#     Example: NC_004166 | Bacteriophage SPP1 complete nucleotide sequence...
# Processing identifier 144/340: KJ997912
#   ✓ Found 1 sequence(s)
#     Example: KJ997912 | Enterobacteria phage MED1, complete genome...
# Processing identifier 145/340: LN610575
#   ✓ Found 1 sequence(s)
#     Example: LN610575 | Pseudomonas phage vB_PaeM_C2-10_Ab08, complete genome...
# Processing identifier 146/340: NC_011534
#   ✓ Found 1 sequence(s)
#     Example: NC_011534 | Kluyvera phage Kvp1, complete genome...
# Processing identifier 147/340: JX997184.1
#   ✓ Found 1 sequence(s)
#     Example: JX997184 | Paramecium bursaria Chlorella virus OR0704.2.2, partial geno...
# Processing identifier 148/340: NC_019707
#   ✓ Found 1 sequence(s)
#     Example: NC_019707 | Enterobacteria phage M, complete genome...
# Processing identifier 149/340: NC_021563
#   ✓ Found 1 sequence(s)
#     Example: NC_021563 | Serratia phage Eta, complete genome...
# Processing identifier 150/340: NC_015254
#   ✓ Found 1 sequence(s)
#     Example: NC_015254 | Brochothrix phage BL3, complete genome...
# Processing identifier 151/340: JX997178.1
#   ✓ Found 1 sequence(s)
#     Example: JX997178 | Acanthocystis turfacea Chlorella virus NE-JV-3, partial geno...
# Processing identifier 152/340: MG775042
#   ✓ Found 1 sequence(s)
#     Example: MG775042 | Citrobacter phage vB_CroP_CrRp3, complete genome...
# Processing identifier 153/340: NC_001422
#   ✓ Found 1 sequence(s)
#     Example: NC_001422 | Escherichia phage phiX174, complete genome...
# Processing identifier 154/340: NC_009899.1
#   ✓ Found 1 sequence(s)
#     Example: NC_009899 | Paramecium bursaria Chlorella virus AR158, complete genome...
# Processing identifier 155/340: KP869101
#   ✓ Found 1 sequence(s)
#     Example: KP869101 | Escherichia coli O157 typing phage 3, complete genome...
# Processing identifier 156/340: NC_009643
#   ✓ Found 1 sequence(s)
#     Example: NC_009643 | Actinomyces phage Av-1, complete genome...
# Processing identifier 157/340: KY290949
#   ✓ Found 1 sequence(s)
#     Example: KY290949 | Aeromonas phage Asp37, complete genome...
# Processing identifier 158/340: NC_008720
#   ✓ Found 1 sequence(s)
#     Example: NC_008720 | Enterobacteria phage N4, complete genome...
# Processing identifier 159/340: JX997161.1
#   ✓ Found 1 sequence(s)
#     Example: JX997161 | Paramecium bursaria Chlorella virus CVG-1, partial genome...
# Processing identifier 160/340: MT496969
#   ✓ Found 1 sequence(s)
#     Example: MT496969 | Escherichia phage Mt1B1_P3, complete genome...
# Processing identifier 161/340: NC_015263
#   ✓ Found 1 sequence(s)
#     Example: NC_015263 | Lactococcus phage 949, complete genome...
# Processing identifier 162/340: NC_005265
#   ✓ Found 1 sequence(s)
#     Example: NC_005265 | Sulfolobus virus 2, complete genome...
# Processing identifier 163/340: NC_009898.1
#   ✓ Found 1 sequence(s)
#     Example: NC_009898 | Paramecium bursaria Chlorella virus NY2A, complete genome...
# Processing identifier 164/340: NC_015274
#   ✓ Found 1 sequence(s)
#     Example: NC_015274 | Streptococcus phage Dp-1, complete genome...
# Processing identifier 165/340: NC_024391
#   ✓ Found 1 sequence(s)
#     Example: NC_024391 | Staphylococcus phage DW2, complete genome...
# Processing identifier 166/340: MT496970
#   ✓ Found 1 sequence(s)
#     Example: MT496970 | Escherichia phage Mt1B1_P17, complete genome...
# Processing identifier 167/340: NC_026586
#   ✓ Found 1 sequence(s)
#     Example: NC_026586 | Pseudomonas phage vB_PaeM_PAO1_Ab27, complete genome...
# Processing identifier 168/340: JX997155.1
#   ✓ Found 1 sequence(s)
#     Example: JX997155 | Acanthocystis turfacea Chlorella virus Br0604L, partial geno...
# Processing identifier 169/340: NZ_CVTE01000001
#   ✓ Found 1 sequence(s)
#     Example: NZ_CVTE01000001 | Escherichia coli strain AL505, whole genome shotgun sequence...
# Processing identifier 170/340: NC_005833.1
#   ✓ Found 1 sequence(s)
#     Example: NC_005833 | Escherichia phage T1, complete genome...
# Processing identifier 171/340: KU963255
#   ✓ Found 1 sequence(s)
#     Example: KU963255 | Gordonia phage Nymphadora, complete genome...
# Processing identifier 172/340: OV696622
#   ✓ Found 1 sequence(s)
#     Example: OV696622 | Brevibacterium phage Rousseau genome assembly, complete geno...
# Processing identifier 173/340: NC_000929
#   ✓ Found 1 sequence(s)
#     Example: NC_000929 | Enterobacteria phage Mu, complete genome...
# Processing identifier 174/340: CU651637.1
#   ✓ Found 1 sequence(s)
#     Example: CU651637 | Escherichia coli LF82 chromosome, complete sequence...
# Processing identifier 175/340: KC182544
#   ✓ Found 1 sequence(s)
#     Example: KC182544 | Lactococcus phage 936, complete genome...
# Processing identifier 176/340: NC_028834
#   ✓ Found 1 sequence(s)
#     Example: NC_028834 | Achromobacter phage 83-24, complete genome...
# Processing identifier 177/340: JX997163.1
#   ✓ Found 1 sequence(s)
#     Example: JX997163 | Paramecium bursaria Chlorella virus CVM-1, partial genome...
# Processing identifier 178/340: NC_013315
#   ✓ Found 1 sequence(s)
#     Example: NC_013315 | Clostridioides difficile CD196, complete sequence...
# Processing identifier 179/340: NC_002516.2
#   ✓ Found 1 sequence(s)
#     Example: NC_002516 | Pseudomonas aeruginosa PAO1, complete genome...
# Processing identifier 180/340: NC_011523
#   ✓ Found 1 sequence(s)
#     Example: NC_011523 | Bacillus phage AP50, complete genome...
# Processing identifier 181/340: OV696617
#   ✓ Found 1 sequence(s)
#     Example: OV696617 | Glutamicibacter phage Voltaire genome assembly, complete gen...
# Processing identifier 182/340: KC556895
#   ✓ Found 1 sequence(s)
#     Example: KC556895 | Brucella phage R/C, complete genome...
# Processing identifier 183/340: LN610581
#   ✓ Found 1 sequence(s)
#     Example: LN610581 | Pseudomonas phage vB_PaeM_PAO1_Ab04, complete genome...
# Processing identifier 184/340: NC_025447
#   ✓ Found 1 sequence(s)
#     Example: NC_025447 | Escherichia phage 121Q, complete genome...
# Processing identifier 185/340: NC_028760.1
#   ✓ Found 1 sequence(s)
#     Example: NC_028760 | Klebsiella phage KLPN1, complete genome...
# Processing identifier 186/340: NC_021556
#   ✓ Found 1 sequence(s)
#     Example: NC_021556 | Mycobacterium phage Leo, complete genome...
# Processing identifier 187/340: NC_004629
#   ✓ Found 1 sequence(s)
#     Example: NC_004629 | Pseudomonas phage phiKZ, complete genome...
# Processing identifier 188/340: MT711978
#   ✓ Found 1 sequence(s)
#     Example: MT711978 | Streptomyces phage Endor1, complete genome...
# Processing identifier 189/340: NC_001332
#   ✓ Found 1 sequence(s)
#     Example: NC_001332 | Enterobacteria phage I2-2, complete genome...
# Processing identifier 190/340: NC_018856
#   ✓ Found 1 sequence(s)
#     Example: NC_018856 | Bacillus phage Bastille, complete genome...
# Processing identifier 191/340: NC_001330
#   ✓ Found 1 sequence(s)
#     Example: NC_001330 | Enterobacteria phage alpha3, complete genome...
# Processing identifier 192/340: KC787108
#   ✓ Found 1 sequence(s)
#     Example: KC787108 | Mycobacterium phage DNAIII, complete genome...
# Processing identifier 193/340: OV696620
#   ✓ Found 1 sequence(s)
#     Example: OV696620 | Psychrobacter phage D'Alembert genome assembly, complete gen...
# Processing identifier 194/340: NC_005859.1
#   ✓ Found 1 sequence(s)
#     Example: NC_005859 | Enterobacteria phage T5, complete genome...
# Processing identifier 195/340: NC_009817
#   ✓ Found 1 sequence(s)
#     Example: NC_009817 | Lactococcus phage KSY1, complete genome...
# Processing identifier 196/340: OL770108
#   ✓ Found 1 sequence(s)
#     Example: OL770108 | Escherichia phage CLB_P3, complete genome...
# Processing identifier 197/340: JX997179.1
#   ✓ Found 1 sequence(s)
#     Example: JX997179 | Paramecium bursaria Chlorella virus NE-JV-4, partial genome...
# Processing identifier 198/340: NZ_LT549890
#   ✓ Found 1 sequence(s)
#     Example: NZ_LT549890 | Saccharolobus solfataricus strain P1 chromosome I...
# Processing identifier 199/340: NC_015294
#   ✓ Found 1 sequence(s)
#     Example: NC_015294 | Pseudomonas phage PAK_P1, complete genome...
# Processing identifier 200/340: JX997165.1
#   ✓ Found 1 sequence(s)
#     Example: JX997165 | Paramecium bursaria Chlorella virus CvsA1, partial genome...
# Processing identifier 201/340: KU998242
#   ✓ Found 1 sequence(s)
#     Example: KU998242 | Gordonia phage Demosthenes, complete genome...
# Processing identifier 202/340: NC_011165
#   ✓ Found 1 sequence(s)
#     Example: NC_011165 | Pseudomonas phage LBL3, complete genome...
# Processing identifier 203/340: NC_001417
#   ✓ Found 1 sequence(s)
#     Example: NC_001417 | phage MS2 genome...
# Processing identifier 204/340: KP869105
#   ✓ Found 1 sequence(s)
#     Example: KP869105 | Escherichia coli O157 typing phage 7, partial genome...
# Processing identifier 205/340: NC_018831
#   ✓ Found 1 sequence(s)
#     Example: NC_018831 | Listeria phage P70, complete genome...
# Processing identifier 206/340: MN876845
#   ✓ Found 1 sequence(s)
#     Example: MN876845 | Pyrobaculum spherical virus 2 isolate 10, complete genome...
# Processing identifier 207/340: NC_011810
#   ✓ Found 1 sequence(s)
#     Example: NC_011810 | Pseudomonas phage PB1, complete genome...
# Processing identifier 208/340: NC_001335
#   ✓ Found 1 sequence(s)
#     Example: NC_001335 | Mycobacterium phage L5 complete genome...
# Processing identifier 209/340: NC_028835
#   ✓ Found 1 sequence(s)
#     Example: NC_028835 | Lactobacillus phage CL2, complete genome...
# Processing identifier 210/340: NC_043235.1
#   ✓ Found 1 sequence(s)
#     Example: NC_043235 | Paramecium bursaria Chlorella virus NYs1, partial genome...
# Processing identifier 211/340: KP869104
#   ✓ Found 1 sequence(s)
#     Example: KP869104 | Escherichia coli O157 typing phage 6, complete genome...
# Processing identifier 212/340: NC_008363
#   ✓ Found 1 sequence(s)
#     Example: NC_008363 | Lactococcus phage P008, complete genome...
# Processing identifier 213/340: JX997174.1
#   ✓ Found 1 sequence(s)
#     Example: JX997174 | Acanthocystis turfacea Chlorella virus MN0810.1, partial gen...
# Processing identifier 214/340: NC_004928
#   ✓ Found 1 sequence(s)
#     Example: NC_004928 | Enterobacteria phage RB69, complete genome...
# Processing identifier 215/340: CP007799.1
#   ✓ Found 1 sequence(s)
#     Example: CP007799 | Escherichia coli Nissle 1917, complete genome...
# Processing identifier 216/340: KP869113
#   ✓ Found 1 sequence(s)
#     Example: KP869113 | Escherichia coli O157 typing phage 15, partial genome...
# Processing identifier 217/340: NC_001338
#   ✓ Found 1 sequence(s)
#     Example: NC_001338 | Sulfolobus virus 1 complete genome (provirus)...
# Processing identifier 218/340: NC_008724.1
#   ✓ Found 1 sequence(s)
#     Example: NC_008724 | Acanthocystis turfacea Chlorella virus 1, complete genome...
# Processing identifier 219/340: KU998249
#   ✓ Found 1 sequence(s)
#     Example: KU998249 | Gordonia phage Soups, complete genome...
# Processing identifier 220/340: LT594786
#   ✓ Found 1 sequence(s)
#     Example: LT594786 | Pseudomonas aeruginosa isolate ph_PII10A genome assembly, ch...
# Processing identifier 221/340: MK165087
#   ✓ Found 1 sequence(s)
#     Example: MK165087 | Escherichia phage BRET, complete genome...
# Processing identifier 222/340: NC_018284
#   ✓ Found 1 sequence(s)
#     Example: NC_018284 | Staphylococcus phage vB_SepiS-phiIPLA7, complete genome...
# Processing identifier 223/340: NC_022986
#   ✓ Found 1 sequence(s)
#     Example: NC_022986 | Pseudomonas phage PAK_P4, complete genome...
# Processing identifier 224/340: NZ_JRWU00000000.1
#   ✓ Found 1 sequence(s)
#     Example: NZ_JRWU00000000 | Rouxiella chamberiensis strain 130333, whole genome shotgun ...
# Processing identifier 225/340: NC_028905
#   ✓ Found 1 sequence(s)
#     Example: NC_028905 | Clostridium phage phiCD111, complete genome...
# Processing identifier 226/340: KP869100
#   ✓ Found 1 sequence(s)
#     Example: KP869100 | Escherichia coli O157 typing phage 1, complete genome...
# Processing identifier 227/340: DQ163914
#   ✓ Found 1 sequence(s)
#     Example: DQ163914 | Pseudomonas phage 119X, complete genome...
# Processing identifier 228/340: NC_001697
#   ✓ Found 1 sequence(s)
#     Example: NC_001697 | Haemophilus phage HP1 strain HP1c1, complete genome...
# Processing identifier 229/340: KC109329
#   ✓ Found 1 sequence(s)
#     Example: KC109329 | Escherichia phage CLB_P1, complete genome...
# Processing identifier 230/340: NC_006557
#   ✓ Found 1 sequence(s)
#     Example: NC_006557 | Bacillus phage BCJA1c, complete genome...
# Processing identifier 231/340: NC_004066
#   ✓ Found 1 sequence(s)
#     Example: NC_004066 | Lactococcus phage ul36, complete genome...
# Processing identifier 232/340: KC556893
#   ✓ Found 1 sequence(s)
#     Example: KC556893 | Brucella phage Bk, complete genome...
# Processing identifier 233/340: JX997154.1
#   ✓ Found 1 sequence(s)
#     Example: JX997154 | Paramecium bursaria Chlorella virus AP110A, partial genome...
# Processing identifier 234/340: NC_028883
#   ✓ Found 1 sequence(s)
#     Example: NC_028883 | Clostridium phage phiMMP01, complete genome...
# Processing identifier 235/340: NC_008603.1
#   ✓ Found 1 sequence(s)
#     Example: NC_008603 | Paramecium bursaria Chlorella virus FR483, complete genome...
# Processing identifier 236/340: NC_015250
#   ✓ Found 1 sequence(s)
#     Example: NC_015250 | Acinetobacter phage 133 strain Acj133, complete genome...
# Processing identifier 237/340: NC_011421
#   ✓ Found 1 sequence(s)
#     Example: NC_011421 | Bacillus phage SPO1, complete genome...
# Processing identifier 238/340: NC_001900
#   ✓ Found 1 sequence(s)
#     Example: NC_001900 | Mycobacterium virus D29, complete genome...
# Processing identifier 239/340: NC_005258
#   ✓ Found 1 sequence(s)
#     Example: NC_005258 | Bacillus phage Bam35c, complete genome...
# Processing identifier 240/340: FN668944
#   ✓ Found 1 sequence(s)
#     Example: FN668944 | Clostridium difficile BI9 chromosome...
# Processing identifier 241/340: LN610586
#   ✓ Found 1 sequence(s)
#     Example: LN610586 | Pseudomonas phage vB_PaeM_C2-10_Ab10, complete genome...
# Processing identifier 242/340: JX997168.1
#   ✓ Found 1 sequence(s)
#     Example: JX997168 | Acanthocystis turfacea Chlorella virus GM0701.1, partial gen...
# Processing identifier 243/340: NC_004302
#   ✓ Found 1 sequence(s)
#     Example: NC_004302 | Lactococcus phage r1t, complete genome...
# Processing identifier 244/340: NC_011748.1
#   ✓ Found 1 sequence(s)
#     Example: NC_011748 | Escherichia coli 55989, complete sequence...
# Processing identifier 245/340: NC_017634.1
#   ✓ Found 1 sequence(s)
#     Example: NC_017634 | Escherichia coli O83:H1 str. NRG 857C, complete sequence...
# Processing identifier 246/340: NC_015253
#   ✓ Found 1 sequence(s)
#     Example: NC_015253 | Brochothrix phage A9, complete genome...
# Processing identifier 247/340: KC556894
#   ✓ Found 1 sequence(s)
#     Example: KC556894 | Brucella phage Fz, complete genome...
# Processing identifier 248/340: NC_044937.1
#   ✓ Found 1 sequence(s)
#     Example: NC_044937 | Paramecium bursaria Chlorella virus CVA-1, partial genome...
# Processing identifier 249/340: MT104471
#   ✓ Found 1 sequence(s)
#     Example: MT104471 | Pseudomonas phage MR8, complete genome...
# Processing identifier 250/340: NC_010275.2
#   ✓ Found 1 sequence(s)
#     Example: NC_010275 | Vibrio phage kappa proviral DNA, complete genome...
# Processing identifier 251/340: JX997187.1
#   ✓ Found 1 sequence(s)
#     Example: JX997187 | Acanthocystis turfacea Chlorella virus WI0606, partial genom...
# Processing identifier 252/340: NC_022974
#   ✓ Found 1 sequence(s)
#     Example: NC_022974 | Pseudomonas phage CHA_P1, complete genome...
# Processing identifier 253/340: NC_001978
#   ✓ Found 1 sequence(s)
#     Example: NC_001978 | Bacteriophage phi-C31 complete genome...
# Processing identifier 254/340: KY629621
#   ✓ Found 1 sequence(s)
#     Example: KY629621 | Streptococcus virus MS1, complete genome...
# Processing identifier 255/340: NC_004112
#   ✓ Found 1 sequence(s)
#     Example: NC_004112 | Lactobacillus phage A2, complete genome...
# Processing identifier 256/340: NC_005830
#   ✓ Found 1 sequence(s)
#     Example: NC_005830 | Acidianus filamentous virus 1, complete genome...
# Processing identifier 257/340: NC_016563
#   ✓ Found 1 sequence(s)
#     Example: NC_016563 | Bacillus phage W.Ph., complete genome...
# Processing identifier 258/340: NC_013692
#   ✓ Found 1 sequence(s)
#     Example: NC_013692 | Pseudomonas phage LIT1, complete genome...
# Processing identifier 259/340: NC_004678
#   ✓ Found 1 sequence(s)
#     Example: NC_004678 | Staphylococcus phage phi44AHJD, complete genome...
# Processing identifier 260/340: NC_018281
#   ✓ Found 1 sequence(s)
#     Example: NC_018281 | Staphylococcus phage vB_SepiS-phiIPLA5, complete genome...
# Processing identifier 261/340: LN610585
#   ✓ Found 1 sequence(s)
#     Example: LN610585 | Pseudomonas phage vB_PaeS_PAO1_Ab20, complete genome...
# Processing identifier 262/340: JX997180.1
#   ✓ Found 1 sequence(s)
#     Example: JX997180 | Acanthocystis turfacea Chlorella virus NTS-1, partial genome...
# Processing identifier 263/340: NC_008253.1
#   ✓ Found 1 sequence(s)
#     Example: NC_008253 | Escherichia coli 536, complete sequence...
# Processing identifier 264/340: NC_003298.1
#   ✓ Found 1 sequence(s)
#     Example: NC_003298 | Enterobacteria phage T3, complete genome...
# Processing identifier 265/340: JX997160.1
#   ✓ Found 1 sequence(s)
#     Example: JX997160 | Paramecium bursaria Chlorella virus CVB-1, partial genome...
# Processing identifier 266/340: NC_002796
#   ✓ Found 1 sequence(s)
#     Example: NC_002796 | Lactococcus phage BK5-T, complete genome...
# Processing identifier 267/340: NC_017972
#   ✓ Found 1 sequence(s)
#     Example: NC_017972 | Pseudomonas phage Lu11, complete genome...
# Processing identifier 268/340: NC_005083
#   ✓ Found 1 sequence(s)
#     Example: NC_005083 | Vibrio phage KVP40, complete genome...
# Processing identifier 269/340: JX997182.1
#   ✓ Found 1 sequence(s)
#     Example: JX997182 | Paramecium bursaria Chlorella virus NY-2B, partial genome...
# Processing identifier 270/340: NC_012741
#   ✓ Found 1 sequence(s)
#     Example: NC_012741 | Enterobacteria phage JS10, complete genome...
# Processing identifier 271/340: NC_028959
#   ✓ Found 1 sequence(s)
#     Example: NC_028959 | Clostridium phage phiMMP03, complete genome...
# Processing identifier 272/340: NC_007458
#   ✓ Found 1 sequence(s)
#     Example: NC_007458 | Bacillus phage Gamma, complete genome...
# Processing identifier 273/340: NC_019487
#   ✓ Found 1 sequence(s)
#     Example: NC_019487 | Bacillus phage SP10, complete genome...
# Processing identifier 274/340: MF398190.1
#   ✓ Found 1 sequence(s)
#     Example: MF398190 | Staphylococcus phage vB_SauM-fRuSau02, complete genome...
# Processing identifier 275/340: KR935217
#   ✓ Found 1 sequence(s)
#     Example: KR935217 | Rhodobacter phage RcCronus, complete genome...
# Processing identifier 276/340: NC_005356
#   ✓ Found 1 sequence(s)
#     Example: NC_005356 | Staphylococcus phage 77, complete genome...
# Processing identifier 277/340: KY290950
#   ✓ Found 1 sequence(s)
#     Example: KY290950 | Aeromonas phage 59.1, complete genome...
# Processing identifier 278/340: NC_007053
#   ✓ Found 1 sequence(s)
#     Example: NC_007053 | Staphylococcus phage 3A, complete genome...
# Processing identifier 279/340: NC_000867
#   ✓ Found 1 sequence(s)
#     Example: NC_000867 | Pseudoalteromonas phage PM2, complete genome...
# Processing identifier 280/340: NC_010353
#   ✓ Found 1 sequence(s)
#     Example: NC_010353 | Streptococcus phage 858, complete genome...
# Processing identifier 281/340: NC_021790
#   ✓ Found 1 sequence(s)
#     Example: NC_021790 | Cellulophaga phage phi18:1, complete genome...
# Processing identifier 282/340: LN907801
#   ✓ Found 1 sequence(s)
#     Example: LN907801 | unidentified phage genome assembly 2P1, chromosome : 2P1...
# Processing identifier 283/340: NC_023585
#   ✓ Found 1 sequence(s)
#     Example: NC_023585 | Sulfolobus monocaudavirus SMV1 complete genome...
# Processing identifier 284/340: NC_001271
#   ✓ Found 1 sequence(s)
#     Example: NC_001271 | Yersinia phage phiYeO3-12, complete genome...
# Processing identifier 285/340: NC_001835
#   ✓ Found 1 sequence(s)
#     Example: NC_001835 | Lactococcus phage sk1, complete genome...
# Processing identifier 286/340: EU887664
#   ✓ Found 1 sequence(s)
#     Example: EU887664 | Bacillus phage TP21-L, complete genome...
# Processing identifier 287/340: KP869106
#   ✓ Found 1 sequence(s)
#     Example: KP869106 | Escherichia coli O157 typing phage 8, partial genome...
# Processing identifier 288/340: MZ868716
#   ✓ Found 1 sequence(s)
#     Example: MZ868716 | Pseudomonas phage pphageT12, complete genome...
# Processing identifier 289/340: NC_003524
#   ✓ Found 1 sequence(s)
#     Example: NC_003524 | Clostridium phage phi3626, complete genome...
# Processing identifier 290/340: NC_005260
#   ✓ Found 1 sequence(s)
#     Example: NC_005260 | Aeromonas phage Aeh1, complete genome...
# Processing identifier 291/340: NC_015252
#   ✓ Found 1 sequence(s)
#     Example: NC_015252 | Brochothrix phage NF5, complete genome...
# Processing identifier 292/340: KC556898
#   ✓ Found 1 sequence(s)
#     Example: KC556898 | Brucella phage Wb, complete genome...
# Processing identifier 293/340: NC_019457
#   ✓ Found 1 sequence(s)
#     Example: NC_019457 | Vibrio phage CP-T1, complete genome...
# Processing identifier 294/340: JX997177.1
#   ✓ Found 1 sequence(s)
#     Example: JX997177 | Acanthocystis turfacea Chlorella virus NE-JV-2, partial geno...
# Processing identifier 295/340: KP869102
#   ✓ Found 1 sequence(s)
#     Example: KP869102 | Escherichia coli O157 typing phage 4, partial genome...
# Processing identifier 296/340: NC_005066
#   ✓ Found 1 sequence(s)
#     Example: NC_005066 | Enterobacteria phage RB49, complete genome...
# Processing identifier 297/340: NC_009811
#   ✓ Found 1 sequence(s)
#     Example: NC_009811 | Listeria phage A511, complete genome...
# Processing identifier 298/340: NC_003214
#   ✓ Found 1 sequence(s)
#     Example: NC_003214 | Sulfolobus islandicus filamentous virus, complete genome...
# Processing identifier 299/340: NC_031245
#   ✓ Found 1 sequence(s)
#     Example: NC_031245 | Bacillus phage SP-15, complete genome...
# Processing identifier 300/340: NC_001604.1
#   ✓ Found 1 sequence(s)
#     Example: NC_001604 | Enterobacteria phage T7, complete genome...
# Processing identifier 301/340: DQ163913
#   ✓ Found 1 sequence(s)
#     Example: DQ163913 | Bacteriophage PA73, complete genome...
# Processing identifier 302/340: DQ163916
#   ✓ Found 1 sequence(s)
#     Example: DQ163916 | Pseudomonas phage M6, complete genome...
# Processing identifier 303/340: KY290952
#   ✓ Found 1 sequence(s)
#     Example: KY290952 | Aeromonas phage 32, complete genome...
# Processing identifier 304/340: NZ_HG326223.1
#   ✓ Found 1 sequence(s)
#     Example: NZ_HG326223 | Serratia marcescens subsp. marcescens Db11 chromosome I, com...
# Processing identifier 305/340: JX997172.1
#   ✓ Found 1 sequence(s)
#     Example: JX997172 | Paramecium bursaria Chlorella virus MA-1D, partial genome...
# Processing identifier 306/340: NC_021529
#   ✓ Found 1 sequence(s)
#     Example: NC_021529 | Vibrio phage nt-1, complete genome...
# Processing identifier 307/340: KP869107
#   ✓ Found 1 sequence(s)
#     Example: KP869107 | Escherichia coli O157 typing phage 9, partial genome...
# Processing identifier 308/340: MZ868715
#   ✓ Found 1 sequence(s)
#     Example: MZ868715 | Pseudomonas phage pphageT21, complete genome...
# Processing identifier 309/340: NC_028765
#   ✓ Found 1 sequence(s)
#     Example: NC_028765 | Staphylococcus phage phiIPLA-RODI, complete genome...
# Processing identifier 310/340: NC_017276
#   ✓ Found 1 sequence(s)
#     Example: NC_017276 | Saccharolobus islandicus REY15A, complete sequence...
# Processing identifier 311/340: NC_028951
#   ✓ Found 1 sequence(s)
#     Example: NC_028951 | Clostridium phage phiCD481-1, complete genome...
# Processing identifier 312/340: NC_019405
#   ✓ Found 1 sequence(s)
#     Example: NC_019405 | Caulobacter phage phiCbK, complete genome...
# Processing identifier 313/340: NC_010326
#   ✓ Found 1 sequence(s)
#     Example: NC_010326 | Pseudomonas phage LUZ19, complete genome...
# Processing identifier 314/340: NC_005891
#   ✓ Found 1 sequence(s)
#     Example: NC_005891 | Vibrio phage VP5, complete genome...
# Processing identifier 315/340: NZ_CP009124
#   ✓ Found 1 sequence(s)
#     Example: NZ_CP009124 | Streptomyces lividans TK24 chromosome, complete genome...
# Processing identifier 316/340: KC787107
#   ✓ Found 1 sequence(s)
#     Example: KC787107 | Mycobacterium phage Bo4, complete genome...
# Processing identifier 317/340: NC_001706
#   ✓ Found 1 sequence(s)
#     Example: NC_001706 | Lactobacillus phage c2, complete genome...
# Processing identifier 318/340: NC_000852.5
#   ✓ Found 1 sequence(s)
#     Example: NC_000852 | Paramecium bursaria Chlorella virus 1, complete genome...
# Processing identifier 319/340: NC_019521
#   ✓ Found 1 sequence(s)
#     Example: NC_019521 | Sphingomonas phage PAU, complete genome...
# Processing identifier 320/340: NC_021058
#   ✓ Found 1 sequence(s)
#     Example: NC_021058 | Saccharolobus islandicus LAL14/1, complete sequence...
# Processing identifier 321/340: NC_001629
#   ✓ Found 1 sequence(s)
#     Example: NC_001629 | Lactococcus phage bIL67, complete genome...
# Processing identifier 322/340: MN876844
#   ✓ Found 1 sequence(s)
#     Example: MN876844 | Pyrobaculum filamentous virus 2 isolate 4, complete genome...
# Processing identifier 323/340: NC_010576
#   ✓ Found 1 sequence(s)
#     Example: NC_010576 | Lactococcus phage 1706, complete genome...
# Processing identifier 324/340: KP869109
#   ✓ Found 1 sequence(s)
#     Example: KP869109 | Escherichia coli O157 typing phage 11, complete genome...
# Processing identifier 325/340: NC_004665
#   ✓ Found 1 sequence(s)
#     Example: NC_004665 | Pseudomonas phage gh-1, complete genome...
# Processing identifier 326/340: NC_019421
#   ✓ Found 1 sequence(s)
#     Example: NC_019421 | Clostridium phage phiMMP02, complete genome...
# Processing identifier 327/340: NC_005880
#   ✓ Found 1 sequence(s)
#     Example: NC_005880 | Staphylococcus phage K, complete genome...
# Processing identifier 328/340: KJ572844.2
#   ✓ Found 1 sequence(s)
#     Example: KJ572844 | Vibrio phage 24, complete genome...
# Processing identifier 329/340: JX997153.1
#   ✓ Found 1 sequence(s)
#     Example: JX997153 | Paramecium bursaria Chlorella virus AN69C, partial genome...
# Processing identifier 330/340: NC_017275
#   ✓ Found 1 sequence(s)
#     Example: NC_017275 | Saccharolobus islandicus HVE10/4, complete sequence...
# Processing identifier 331/340: MG775043
#   ✓ Found 1 sequence(s)
#     Example: MG775043 | Citrobacter phage vB_CroM_CrRp10, complete genome...
# Processing identifier 332/340: MT740307
#   ✓ Found 1 sequence(s)
#     Example: MT740307 | Pseudomonas phage phiK7A1, complete genome...
# Processing identifier 333/340: KU998240
#   ✓ Found 1 sequence(s)
#     Example: KU998240 | Gordonia phage Woes, complete genome...
# Processing identifier 334/340: NC_022970
#   ✓ Found 1 sequence(s)
#     Example: NC_022970 | Pseudomonas phage PAK_P3, complete genome...
# Processing identifier 335/340: KY290947
#   ✓ Found 1 sequence(s)
#     Example: KY290947 | Aeromonas phage 3, complete genome...
# Processing identifier 336/340: NC_006945
#   ✓ Found 1 sequence(s)
#     Example: NC_006945 | Bacillus phage GIL16c, complete genome...
# Processing identifier 337/340: NC_007051
#   ✓ Found 1 sequence(s)
#     Example: NC_007051 | Staphylococcus phage 2638A, complete genome...
# Processing identifier 338/340: NC_001416
#   ✓ Found 1 sequence(s)
#     Example: NC_001416 | Enterobacteria phage lambda, complete genome...
# Processing identifier 339/340: MZ868713
#   ✓ Found 1 sequence(s)
#     Example: MZ868713 | Pseudomonas phage psageK4e, complete genome...
# Processing identifier 340/340: HG738867
#   ✓ Found 1 sequence(s)
#     Example: HG738867 | Escherichia coli str. K-12 substr. MC4100 complete genome...
#
# ==================================================
# FINAL SUMMARY:
# ==================================================
# Success rate: 340/340 (100.0%)
# Total sequences found: 340
# Average sequences per successful identifier: 1.0
#
# Detailed results:
# ✓ DQ838728: 1 sequences
# ✓ NC_019446: 1 sequences
# ✓ HG962376: 1 sequences
# ✓ MT354569: 1 sequences
# ✓ CP003316: 1 sequences
# ✓ KY290954: 1 sequences
# ✓ KP869111: 1 sequences
# ✓ NC_015719: 1 sequences
# ✓ LN610583: 1 sequences
# ✓ NC_028962: 1 sequences
# ✓ NC_023693: 1 sequences
# ✓ NC_031031: 1 sequences
# ✓ NC_028958: 1 sequences
# ✓ NC_026600: 1 sequences
# ✓ NC_002167: 1 sequences
# ✓ NC_004086: 1 sequences
# ✓ KU998234: 1 sequences
# ✓ KU963263: 1 sequences
# ✓ JX997166.1: 1 sequences
# ✓ NC_012663: 1 sequences
# ✓ NC_012884: 1 sequences
# ✓ KP869103: 1 sequences
# ✓ KR935213: 1 sequences
# ✓ MZ348426: 1 sequences
# ✓ MZ348425: 1 sequences
# ✓ NC_013697: 1 sequences
# ✓ NC_008364: 1 sequences
# ✓ NC_018750.1: 1 sequences
# ✓ MT496971: 1 sequences
# ✓ LR657304.1: 1 sequences
# ✓ OL770107: 1 sequences
# ✓ NC_027120: 1 sequences
# ✓ EU863408: 1 sequences
# ✓ NC_007059: 1 sequences
# ✓ JX997156.1: 1 sequences
# ✓ NC_028984: 1 sequences
# ✓ JX997173.1: 1 sequences
# ✓ NC_000913.3: 1 sequences
# ✓ NC_005178: 1 sequences
# ✓ NC_013645: 1 sequences
# ✓ NC_002703: 1 sequences
# ✓ KP869112: 1 sequences
# ✓ KY290955: 1 sequences
# ✓ JX997176.1: 1 sequences
# ✓ NC_024140: 1 sequences
# ✓ NC_010325: 1 sequences
# ✓ NC_002484: 1 sequences
# ✓ JX997181.1: 1 sequences
# ✓ JX997175.1: 1 sequences
# ✓ ADIC00000000.1: 1 sequences
# ✓ NC_019422: 1 sequences
# ✓ OV696619: 1 sequences
# ✓ NC_029080: 1 sequences
# ✓ NC_002649: 1 sequences
# ✓ JX997170.1: 1 sequences
# ✓ NC_021788: 1 sequences
# ✓ KU998244: 1 sequences
# ✓ KY290948: 1 sequences
# ✓ KY290953: 1 sequences
# ✓ MN876842: 1 sequences
# ✓ LN610582: 1 sequences
# ✓ KU998237: 1 sequences
# ✓ NC_015518: 1 sequences
# ✓ LN610578: 1 sequences
# ✓ NC_022966: 1 sequences
# ✓ LN610576: 1 sequences
# ✓ NC_007047: 1 sequences
# ✓ JX997158.1: 1 sequences
# ✓ JX997169.1: 1 sequences
# ✓ NC_005948: 1 sequences
# ✓ KJ617393: 1 sequences
# ✓ AY441783: 1 sequences
# ✓ NZ_CP028714.1: 1 sequences
# ✓ MZ868717: 1 sequences
# ✓ DQ529280: 1 sequences
# ✓ MT711976: 1 sequences
# ✓ JX997186.1: 1 sequences
# ✓ NC_008584: 1 sequences
# ✓ NC_014660: 1 sequences
# ✓ NC_002700: 1 sequences
# ✓ NC_042115: 1 sequences
# ✓ NC_032001.1: 1 sequences
# ✓ MT711975: 1 sequences
# ✓ KY290951: 1 sequences
# ✓ JX997157.1: 1 sequences
# ✓ NC_002072: 1 sequences
# ✓ GQ979703: 1 sequences
# ✓ MT711977: 1 sequences
# ✓ EU863409: 1 sequences
# ✓ NC_001909: 1 sequences
# ✓ KC556896: 1 sequences
# ✓ EF108465: 1 sequences
# ✓ NC_020416: 1 sequences
# ✓ JX997164.1: 1 sequences
# ✓ NC_001331: 1 sequences
# ✓ NC_000866.4: 1 sequences
# ✓ NC_001628: 1 sequences
# ✓ NC_028764: 1 sequences
# ✓ JX997162.1: 1 sequences
# ✓ NC_028888: 1 sequences
# ✓ NC_013598: 1 sequences
# ✓ LT594787: 1 sequences
# ✓ MZ868714: 1 sequences
# ✓ NC_022757: 1 sequences
# ✓ KC862296: 1 sequences
# ✓ NC_015568: 1 sequences
# ✓ KP869108: 1 sequences
# ✓ CP009273.1: 1 sequences
# ✓ NC_011048: 1 sequences
# ✓ KP869110: 1 sequences
# ✓ DQ163912: 1 sequences
# ✓ NC_019813: 1 sequences
# ✓ NC_023719: 1 sequences
# ✓ DQ491001.1: 1 sequences
# ✓ NC_030884: 1 sequences
# ✓ NZ_LN874954.1: 1 sequences
# ✓ DQ163917: 1 sequences
# ✓ NC_026602: 1 sequences
# ✓ NC_038017: 1 sequences
# ✓ NC_002754: 1 sequences
# ✓ NC_002371: 1 sequences
# ✓ NC_022967: 1 sequences
# ✓ NC_026594: 1 sequences
# ✓ JX997185.1: 1 sequences
# ✓ LN610588: 1 sequences
# ✓ LT717094: 1 sequences
# ✓ NC_026587: 1 sequences
# ✓ LT821717: 1 sequences
# ✓ NC_019918: 1 sequences
# ✓ KY579375: 1 sequences
# ✓ NC_026601: 1 sequences
# ✓ MT711979: 1 sequences
# ✓ NC_029548: 1 sequences
# ✓ NC_001895: 1 sequences
# ✓ KU963247: 1 sequences
# ✓ JX997171.1: 1 sequences
# ✓ NC_028838: 1 sequences
# ✓ MT354570: 1 sequences
# ✓ NC_025422: 1 sequences
# ✓ OV696621: 1 sequences
# ✓ NC_007019: 1 sequences
# ✓ JX997167.1: 1 sequences
# ✓ NC_004166: 1 sequences
# ✓ KJ997912: 1 sequences
# ✓ LN610575: 1 sequences
# ✓ NC_011534: 1 sequences
# ✓ JX997184.1: 1 sequences
# ✓ NC_019707: 1 sequences
# ✓ NC_021563: 1 sequences
# ✓ NC_015254: 1 sequences
# ✓ JX997178.1: 1 sequences
# ✓ MG775042: 1 sequences
# ✓ NC_001422: 1 sequences
# ✓ NC_009899.1: 1 sequences
# ✓ KP869101: 1 sequences
# ✓ NC_009643: 1 sequences
# ✓ KY290949: 1 sequences
# ✓ NC_008720: 1 sequences
# ✓ JX997161.1: 1 sequences
# ✓ MT496969: 1 sequences
# ✓ NC_015263: 1 sequences
# ✓ NC_005265: 1 sequences
# ✓ NC_009898.1: 1 sequences
# ✓ NC_015274: 1 sequences
# ✓ NC_024391: 1 sequences
# ✓ MT496970: 1 sequences
# ✓ NC_026586: 1 sequences
# ✓ JX997155.1: 1 sequences
# ✓ NZ_CVTE01000001: 1 sequences
# ✓ NC_005833.1: 1 sequences
# ✓ KU963255: 1 sequences
# ✓ OV696622: 1 sequences
# ✓ NC_000929: 1 sequences
# ✓ CU651637.1: 1 sequences
# ✓ KC182544: 1 sequences
# ✓ NC_028834: 1 sequences
# ✓ JX997163.1: 1 sequences
# ✓ NC_013315: 1 sequences
# ✓ NC_002516.2: 1 sequences
# ✓ NC_011523: 1 sequences
# ✓ OV696617: 1 sequences
# ✓ KC556895: 1 sequences
# ✓ LN610581: 1 sequences
# ✓ NC_025447: 1 sequences
# ✓ NC_028760.1: 1 sequences
# ✓ NC_021556: 1 sequences
# ✓ NC_004629: 1 sequences
# ✓ MT711978: 1 sequences
# ✓ NC_001332: 1 sequences
# ✓ NC_018856: 1 sequences
# ✓ NC_001330: 1 sequences
# ✓ KC787108: 1 sequences
# ✓ OV696620: 1 sequences
# ✓ NC_005859.1: 1 sequences
# ✓ NC_009817: 1 sequences
# ✓ OL770108: 1 sequences
# ✓ JX997179.1: 1 sequences
# ✓ NZ_LT549890: 1 sequences
# ✓ NC_015294: 1 sequences
# ✓ JX997165.1: 1 sequences
# ✓ KU998242: 1 sequences
# ✓ NC_011165: 1 sequences
# ✓ NC_001417: 1 sequences
# ✓ KP869105: 1 sequences
# ✓ NC_018831: 1 sequences
# ✓ MN876845: 1 sequences
# ✓ NC_011810: 1 sequences
# ✓ NC_001335: 1 sequences
# ✓ NC_028835: 1 sequences
# ✓ NC_043235.1: 1 sequences
# ✓ KP869104: 1 sequences
# ✓ NC_008363: 1 sequences
# ✓ JX997174.1: 1 sequences
# ✓ NC_004928: 1 sequences
# ✓ CP007799.1: 1 sequences
# ✓ KP869113: 1 sequences
# ✓ NC_001338: 1 sequences
# ✓ NC_008724.1: 1 sequences
# ✓ KU998249: 1 sequences
# ✓ LT594786: 1 sequences
# ✓ MK165087: 1 sequences
# ✓ NC_018284: 1 sequences
# ✓ NC_022986: 1 sequences
# ✓ NZ_JRWU00000000.1: 1 sequences
# ✓ NC_028905: 1 sequences
# ✓ KP869100: 1 sequences
# ✓ DQ163914: 1 sequences
# ✓ NC_001697: 1 sequences
# ✓ KC109329: 1 sequences
# ✓ NC_006557: 1 sequences
# ✓ NC_004066: 1 sequences
# ✓ KC556893: 1 sequences
# ✓ JX997154.1: 1 sequences
# ✓ NC_028883: 1 sequences
# ✓ NC_008603.1: 1 sequences
# ✓ NC_015250: 1 sequences
# ✓ NC_011421: 1 sequences
# ✓ NC_001900: 1 sequences
# ✓ NC_005258: 1 sequences
# ✓ FN668944: 1 sequences
# ✓ LN610586: 1 sequences
# ✓ JX997168.1: 1 sequences
# ✓ NC_004302: 1 sequences
# ✓ NC_011748.1: 1 sequences
# ✓ NC_017634.1: 1 sequences
# ✓ NC_015253: 1 sequences
# ✓ KC556894: 1 sequences
# ✓ NC_044937.1: 1 sequences
# ✓ MT104471: 1 sequences
# ✓ NC_010275.2: 1 sequences
# ✓ JX997187.1: 1 sequences
# ✓ NC_022974: 1 sequences
# ✓ NC_001978: 1 sequences
# ✓ KY629621: 1 sequences
# ✓ NC_004112: 1 sequences
# ✓ NC_005830: 1 sequences
# ✓ NC_016563: 1 sequences
# ✓ NC_013692: 1 sequences
# ✓ NC_004678: 1 sequences
# ✓ NC_018281: 1 sequences
# ✓ LN610585: 1 sequences
# ✓ JX997180.1: 1 sequences
# ✓ NC_008253.1: 1 sequences
# ✓ NC_003298.1: 1 sequences
# ✓ JX997160.1: 1 sequences
# ✓ NC_002796: 1 sequences
# ✓ NC_017972: 1 sequences
# ✓ NC_005083: 1 sequences
# ✓ JX997182.1: 1 sequences
# ✓ NC_012741: 1 sequences
# ✓ NC_028959: 1 sequences
# ✓ NC_007458: 1 sequences
# ✓ NC_019487: 1 sequences
# ✓ MF398190.1: 1 sequences
# ✓ KR935217: 1 sequences
# ✓ NC_005356: 1 sequences
# ✓ KY290950: 1 sequences
# ✓ NC_007053: 1 sequences
# ✓ NC_000867: 1 sequences
# ✓ NC_010353: 1 sequences
# ✓ NC_021790: 1 sequences
# ✓ LN907801: 1 sequences
# ✓ NC_023585: 1 sequences
# ✓ NC_001271: 1 sequences
# ✓ NC_001835: 1 sequences
# ✓ EU887664: 1 sequences
# ✓ KP869106: 1 sequences
# ✓ MZ868716: 1 sequences
# ✓ NC_003524: 1 sequences
# ✓ NC_005260: 1 sequences
# ✓ NC_015252: 1 sequences
# ✓ KC556898: 1 sequences
# ✓ NC_019457: 1 sequences
# ✓ JX997177.1: 1 sequences
# ✓ KP869102: 1 sequences
# ✓ NC_005066: 1 sequences
# ✓ NC_009811: 1 sequences
# ✓ NC_003214: 1 sequences
# ✓ NC_031245: 1 sequences
# ✓ NC_001604.1: 1 sequences
# ✓ DQ163913: 1 sequences
# ✓ DQ163916: 1 sequences
# ✓ KY290952: 1 sequences
# ✓ NZ_HG326223.1: 1 sequences
# ✓ JX997172.1: 1 sequences
# ✓ NC_021529: 1 sequences
# ✓ KP869107: 1 sequences
# ✓ MZ868715: 1 sequences
# ✓ NC_028765: 1 sequences
# ✓ NC_017276: 1 sequences
# ✓ NC_028951: 1 sequences
# ✓ NC_019405: 1 sequences
# ✓ NC_010326: 1 sequences
# ✓ NC_005891: 1 sequences
# ✓ NZ_CP009124: 1 sequences
# ✓ KC787107: 1 sequences
# ✓ NC_001706: 1 sequences
# ✓ NC_000852.5: 1 sequences
# ✓ NC_019521: 1 sequences
# ✓ NC_021058: 1 sequences
# ✓ NC_001629: 1 sequences
# ✓ MN876844: 1 sequences
# ✓ NC_010576: 1 sequences
# ✓ KP869109: 1 sequences
# ✓ NC_004665: 1 sequences
# ✓ NC_019421: 1 sequences
# ✓ NC_005880: 1 sequences
# ✓ KJ572844.2: 1 sequences
# ✓ JX997153.1: 1 sequences
# ✓ NC_017275: 1 sequences
# ✓ MG775043: 1 sequences
# ✓ MT740307: 1 sequences
# ✓ KU998240: 1 sequences
# ✓ NC_022970: 1 sequences
# ✓ KY290947: 1 sequences
# ✓ NC_006945: 1 sequences
# ✓ NC_007051: 1 sequences
# ✓ NC_001416: 1 sequences
# ✓ MZ868713: 1 sequences
# ✓ HG738867: 1 sequences
#
# Sequence count distribution:
# Min sequences: 1
# Max sequences: 1
# Median sequences: 1.0
#
# Results stored in variables:
# - search_results: detailed results dictionary
# - search_summary: summary DataFrame
